# %%
import json
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# fetch HTML and CSS content
def fetch_content(base_url, relative_url):
    full_url = urljoin(base_url, relative_url)
    try:
        response = requests.get(full_url)
        response.raise_for_status()  # for request errors
    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve {full_url}: {e}")
        return None, None

    html_content = response.content
    soup = BeautifulSoup(html_content, 'html.parser')
    
    css_content = {}
    # external CSS
    for link in soup.find_all('link', rel='stylesheet', href=True):
        css_url = urljoin(full_url, link['href'])
        try:
            css_response = requests.get(css_url)
            css_response.raise_for_status()
            css_content[f"external_{css_url}"] = css_response.text
            print(f"Fetched external CSS from {css_url}")
        except requests.exceptions.RequestException as e:
            print(f"Failed to retrieve external CSS file {css_url}: {e}")

    # internal CSS
    for i, style in enumerate(soup.find_all('style'), 1):
        internal_css = style.string
        if internal_css:
            css_content[f'internal_style_{i}'] = internal_css
            print(f"Found internal CSS within <style> tags {i}")

    # inline CSS
    for tag in soup.find_all(style=True):
        inline_css = tag['style']
        if inline_css:
            css_content[f'inline_style_{tag.name}_{tag.get("class", "")}'] = inline_css
            print(f"Found inline CSS in <{tag.name}> tag")

    return html_content, css_content

# base URL
base_url = 'https://www.haberturk.com'

# load URLs
with open('urls.json', 'r') as file:
    data = json.load(file)

unique_urls = data.get('unique_urls', [])
total_urls = len(unique_urls)

# dictionary to store the CSS files
css_files = {}

# process all URLs
for index, relative_url in enumerate(unique_urls):
    progress = f"({index + 1}/{total_urls})"
    print(f"{progress} Analyzing {urljoin(base_url, relative_url)}...")
    
    _, css_content_dict = fetch_content(base_url, relative_url)
    if css_content_dict:
        for css_key, css_content in css_content_dict.items():
            css_files[css_key] = css_content
        print(f"{progress} Successfully fetched CSS from {urljoin(base_url, relative_url)}")
    else:
        print(f"{progress} No CSS content found for {urljoin(base_url, relative_url)}")

# save CSS data to a JSON file
with open('css_files.json', 'w', encoding='utf-8') as file:
    json.dump(css_files, file, indent=4)

# generate HTML report
html_report = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>CSS File Log</title>
</head>
<body>
    <h1>CSS File Log</h1>
"""
for css_key in css_files:
    css_type = "Internal" if "internal" in css_key else "External" if "external" in css_key else "Inline"
    html_report += f"<h2>{css_type} CSS: {css_key}</h2>\n"
html_report += """
</body>
</html>
"""

# save HTML report to a file
with open('css_file_log.html', 'w', encoding='utf-8') as file:
    file.write(html_report)

print("Logging complete. HTML and JSON reports have been saved.")
# Out:
# (1/536) Analyzing https://www.haberturk.com/images/common/manifest/180x180.png...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (1/536) No CSS content found for https://www.haberturk.com/images/common/manifest/180x180.png
# (2/536) Analyzing https://www.haberturk.com/images/common/favicon/32x32.png...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (2/536) No CSS content found for https://www.haberturk.com/images/common/favicon/32x32.png
# (3/536) Analyzing https://www.haberturk.com/images/common/favicon/16x16.png...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (3/536) No CSS content found for https://www.haberturk.com/images/common/favicon/16x16.png
# (4/536) Analyzing https://www.haberturk.com/images/common/favicon/favicon.ico?v=001...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (4/536) No CSS content found for https://www.haberturk.com/images/common/favicon/favicon.ico?v=001
# (5/536) Analyzing https://www.haberturk.com/manifest.webmanifest...
# (5/536) No CSS content found for https://www.haberturk.com/manifest.webmanifest
# (6/536) Analyzing https://im.haberturk.com...
# (6/536) No CSS content found for https://im.haberturk.com
# (7/536) Analyzing https://adsp.haberturk.com...
# (7/536) No CSS content found for https://adsp.haberturk.com
# (8/536) Analyzing https://im.hthayat.com...
# Failed to retrieve https://im.hthayat.com: HTTPSConnectionPool(host='im.hthayat.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1000)')))
# (8/536) No CSS content found for https://im.hthayat.com
# (9/536) Analyzing https://geoim.bloomberght.com...
# Failed to retrieve https://geoim.bloomberght.com: 403 Client Error: Forbidden for url: https://geoim.bloomberght.com/
# (9/536) No CSS content found for https://geoim.bloomberght.com
# (10/536) Analyzing https://im.showtv.com.tr...
# Failed to retrieve https://im.showtv.com.tr: 403 Client Error: Forbidden for url: https://im.showtv.com.tr/
# (10/536) No CSS content found for https://im.showtv.com.tr
# (11/536) Analyzing https://mo.ciner.com.tr...
# Failed to retrieve https://mo.ciner.com.tr: 403 Client Error: Forbidden for url: https://mo.ciner.com.tr/
# (11/536) No CSS content found for https://mo.ciner.com.tr
# (12/536) Analyzing https://static.criteo.net...
# Failed to retrieve https://static.criteo.net: 404 Client Error: Not Found for url: https://static.criteo.net/
# (12/536) No CSS content found for https://static.criteo.net
# (13/536) Analyzing https://pagead2.googlesyndication.com...
# Failed to retrieve https://pagead2.googlesyndication.com: 404 Client Error: Not Found for url: https://pagead2.googlesyndication.com/
# (13/536) No CSS content found for https://pagead2.googlesyndication.com
# (14/536) Analyzing https://www.google.com...
# Fetched external CSS from https://www.google.com/xjs/_/ss/k=xjs.hp.EKEqW5u2chQ.L.X.O/am=AQAAgAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAIABAIAAAAAAAAAAAAAAAAQABAAYgIA/d=1/ed=1/rs=ACT90oGfnmscktG4JjTjSn4vQnB3qVRVcA/m=sb_he,d
# Found internal CSS within <style> tags 1
# Found internal CSS within <style> tags 2
# Found inline CSS in <a> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <img> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <input> tag
# Found inline CSS in <img> tag
# Found inline CSS in <br> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <p> tag
# (14/536) Successfully fetched CSS from https://www.google.com
# (15/536) Analyzing https://www.google-analytics.com...
# Fetched external CSS from https://fonts.googleapis.com/css?family=Roboto:100,300,400,500,700|Google+Sans:400,500|Product+Sans:400&lang=en
# Fetched external CSS from https://www.gstatic.com/glue/cookienotificationbar/cookienotificationbar.min.css
# Failed to retrieve external CSS file https://www.google-analytics.com/static/css/index.min.css: 404 Client Error: Not Found for url: https://www.google-analytics.com/static/css/index.min.css
# Found internal CSS within <style> tags 1
# Found internal CSS within <style> tags 2
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <stop> tag
# Found inline CSS in <stop> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <g> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <g> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <stop> tag
# Found inline CSS in <stop> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <g> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# Found inline CSS in <path> tag
# Found inline CSS in <use> tag
# Found inline CSS in <g> tag
# Found inline CSS in <use> tag
# Found inline CSS in <path> tag
# (15/536) Successfully fetched CSS from https://www.google-analytics.com
# (16/536) Analyzing https://www.googletagmanager.com...
# Failed to retrieve https://www.googletagmanager.com: 400 Client Error: Bad Request for url: https://www.googletagmanager.com/
# (16/536) No CSS content found for https://www.googletagmanager.com
# (17/536) Analyzing https://www.googletagservices.com...
# Failed to retrieve https://www.googletagservices.com: 404 Client Error: Not Found for url: https://www.googletagservices.com/
# (17/536) No CSS content found for https://www.googletagservices.com
# (18/536) Analyzing https://securepubads.g.doubleclick.net...
# Failed to retrieve https://securepubads.g.doubleclick.net: 404 Client Error: Not Found for url: https://securepubads.g.doubleclick.net/
# (18/536) No CSS content found for https://securepubads.g.doubleclick.net
# (19/536) Analyzing https://www.haberturk.com...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <a> tag
# Found inline CSS in <iframe> tag
# (19/536) Successfully fetched CSS from https://www.haberturk.com
# (20/536) Analyzing https://m.haberturk.com...
# Fetched external CSS from https://m.haberturk.com/css/mobile/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <a> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <a> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (20/536) Successfully fetched CSS from https://m.haberturk.com
# (21/536) Analyzing https://www.haberturk.com/css/desktop/style.css?v=252...
# (21/536) No CSS content found for https://www.haberturk.com/css/desktop/style.css?v=252
# (22/536) Analyzing https://im.haberturk.com/l/2024/06/19/ver1718799771/3696380/jpg/320x640...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (22/536) No CSS content found for https://im.haberturk.com/l/2024/06/19/ver1718799771/3696380/jpg/320x640
# (23/536) Analyzing https://im.haberturk.com/l/2024/06/20/ver1718831744/3696460/jpg/320x640...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (23/536) No CSS content found for https://im.haberturk.com/l/2024/06/20/ver1718831744/3696460/jpg/320x640
# (24/536) Analyzing https://im.haberturk.com/l/2024/06/20/ver1718863122/3696489_manset/jpg/640x640...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (24/536) No CSS content found for https://im.haberturk.com/l/2024/06/20/ver1718863122/3696489_manset/jpg/640x640
# (25/536) Analyzing https://im.haberturk.com/l/2024/06/20/ver1718858199/3696483_manset/jpg/640x640...
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# (25/536) No CSS content found for https://im.haberturk.com/l/2024/06/20/ver1718858199/3696483_manset/jpg/640x640
# (26/536) Analyzing https://www.haberturk.com/adscbg/cbglout.js...
# Found inline CSS in <a> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <d[r];u++){var> tag
# (26/536) Successfully fetched CSS from https://www.haberturk.com/adscbg/cbglout.js
# (27/536) Analyzing https://www.haberturk.com/ekonomi...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (27/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi
# (28/536) Analyzing https://www.haberturk.com/ekonomi/altin...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=256
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (28/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/altin
# (29/536) Analyzing https://www.haberturk.com/ekonomi/piyasa/88-dolar...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (29/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/piyasa/88-dolar
# (30/536) Analyzing https://www.haberturk.com/ekonomi/piyasa/89-euro...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (30/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/piyasa/89-euro
# (31/536) Analyzing https://www.haberturk.com/ekonomi/altin/610-gram-altin...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (31/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/altin/610-gram-altin
# (32/536) Analyzing https://www.haberturk.com/ekonomi/piyasa/1947-faiz...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (32/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/piyasa/1947-faiz
# (33/536) Analyzing https://www.haberturk.com/ekonomi/piyasa/2211-bitcoin...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (33/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/piyasa/2211-bitcoin
# (34/536) Analyzing https://www.haberturk.com/ekonomi/borsa...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (34/536) Successfully fetched CSS from https://www.haberturk.com/ekonomi/borsa
# (35/536) Analyzing https://www.haberturk.com/canliyayin...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Fetched external CSS from https://cdn.radiantmediatechs.com/rmp/7.4.1/css/rmp-s1.min.css
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (35/536) Successfully fetched CSS from https://www.haberturk.com/canliyayin
# (36/536) Analyzing https://www.haberturk.com/...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=256
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <a> tag
# Found inline CSS in <iframe> tag
# (36/536) Successfully fetched CSS from https://www.haberturk.com/
# (37/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Adana/LTAG...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (37/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Adana/LTAG
# (38/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Adiyaman/LTDY...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (38/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Adiyaman/LTDY
# (39/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Afyon/LTAF...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (39/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Afyon/LTAF
# (40/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Agri/LTCB...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (40/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Agri/LTCB
# (41/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Amasya/LTT3...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (41/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Amasya/LTT3
# (42/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Ankara/LTAD...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (42/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Ankara/LTAD
# (43/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Antalya/TU0199...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (43/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Antalya/TU0199
# (44/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Artvin/LTAT...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (44/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Artvin/LTAT
# (45/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Aydin/LT03...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (45/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Aydin/LT03
# (46/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Balikesir/LTBF...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (46/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Balikesir/LTBF
# (47/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Bilecik/LTKY...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (47/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Bilecik/LTKY
# (48/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Bingol/LTT5...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (48/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Bingol/LTT5
# (49/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Bitlis/LT07...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (49/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Bitlis/LT07
# (50/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Bolu/LTT1...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (50/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Bolu/LTT1
# (51/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Burdur/LT08...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (51/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Burdur/LT08
# (52/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Bursa/LTBU...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (52/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Bursa/LTBU
# (53/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Canakkale/LTBH...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (53/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Canakkale/LTBH
# (54/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Cankiri/LT09...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (54/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Cankiri/LT09
# (55/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Corum/LTT2...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (55/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Corum/LTT2
# (56/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Denizli/LT10...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (56/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Denizli/LT10
# (57/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Diyarbakir/LTCC...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (57/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Diyarbakir/LTCC
# (58/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Edirne/LTEI...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (58/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Edirne/LTEI
# (59/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Elazig/LTCA...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (59/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Elazig/LTCA
# (60/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Erzincan/LTCD...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (60/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Erzincan/LTCD
# (61/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Erzurum/LTCE...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (61/536) Successfully fetched CSS from https://www.haberturk.com/havadurumu/Turkiye-TR/Erzurum/LTCE
# (62/536) Analyzing https://www.haberturk.com/havadurumu/Turkiye-TR/Eskisehir/LTES...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# Found inline CSS in <span> tag
# ...
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (525/536) Successfully fetched CSS from https://www.haberturk.com/kiz-isimleri-en-guzel-modern-farkli-dini-turkce-ingilizce-populer-kiz-bebek-isimleri-ve-anlamlari-3563627
# (526/536) Analyzing https://www.haberturk.com/atasozleri-ve-anlamlari...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Fetched external CSS from https://www.haberturk.com/css/vendor/dataTables/datatables.min.css?id=a24661f35e5f0286cd127df5025d25d7
# Fetched external CSS from https://www.haberturk.com/css/vendor/dataTables/dataTables-alphabetSearch.css?id=14de726d4e40a0f8788d46f27e484695
# Found internal CSS within <style> tags 1
# Found internal CSS within <style> tags 2
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (526/536) Successfully fetched CSS from https://www.haberturk.com/atasozleri-ve-anlamlari
# (527/536) Analyzing https://www.haberturk.com/deyimler-sozlugu...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Fetched external CSS from https://www.haberturk.com/css/vendor/dataTables/datatables.min.css?id=a24661f35e5f0286cd127df5025d25d7
# Fetched external CSS from https://www.haberturk.com/css/vendor/dataTables/dataTables-alphabetSearch.css?id=14de726d4e40a0f8788d46f27e484695
# Found internal CSS within <style> tags 1
# Found internal CSS within <style> tags 2
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (527/536) Successfully fetched CSS from https://www.haberturk.com/deyimler-sozlugu
# (528/536) Analyzing https://www.haberturk.com/cin-takvimi-cinsiyet-hesaplama...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <input> tag
# Found inline CSS in <input> tag
# Found inline CSS in <div> tag
# Found inline CSS in <ul> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (528/536) Successfully fetched CSS from https://www.haberturk.com/cin-takvimi-cinsiyet-hesaplama
# (529/536) Analyzing https://www.haberturk.com/iett-sefer-saatleri-ve-otobus-duraklari...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <li> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (529/536) Successfully fetched CSS from https://www.haberturk.com/iett-sefer-saatleri-ve-otobus-duraklari
# (530/536) Analyzing https://www.haberturk.com/gebelik-hesaplama...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <input> tag
# Found inline CSS in <input> tag
# Found inline CSS in <input> tag
# Found inline CSS in <div> tag
# Found inline CSS in <input> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (530/536) Successfully fetched CSS from https://www.haberturk.com/gebelik-hesaplama
# (531/536) Analyzing https://www.haberturk.com/yukselen-burc-hesaplama...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (531/536) Successfully fetched CSS from https://www.haberturk.com/yukselen-burc-hesaplama
# (532/536) Analyzing https://www.haberturk.com/yuzde-hesaplama...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <li> tag
# Found inline CSS in <input> tag
# Found inline CSS in <li> tag
# Found inline CSS in <input> tag
# Found inline CSS in <li> tag
# Found inline CSS in <input> tag
# Found inline CSS in <li> tag
# Found inline CSS in <input> tag
# Found inline CSS in <li> tag
# Found inline CSS in <input> tag
# Found inline CSS in <span> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (532/536) Successfully fetched CSS from https://www.haberturk.com/yuzde-hesaplama
# (533/536) Analyzing https://www.haberturk.com/gecmis-doviz-kurlari/...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=258
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (533/536) Successfully fetched CSS from https://www.haberturk.com/gecmis-doviz-kurlari/
# (534/536) Analyzing https://www.haberturk.com/instagram-dondurma-nasil-yapilir-instagram-gecici-ve-kalici-hesap-dondurma-linki-2024-3671526...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=250
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (534/536) Successfully fetched CSS from https://www.haberturk.com/instagram-dondurma-nasil-yapilir-instagram-gecici-ve-kalici-hesap-dondurma-linki-2024-3671526
# (535/536) Analyzing https://www.haberturk.com/instagram-hesap-silme-nasil-yapilir-instagram-kalici-ve-gecici-hesap-silme-linki-2024-3671557...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=250
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (535/536) Successfully fetched CSS from https://www.haberturk.com/instagram-hesap-silme-nasil-yapilir-instagram-kalici-ve-gecici-hesap-silme-linki-2024-3671557
# (536/536) Analyzing https://www.haberturk.com/2024-yilinda-kac-gun-tatil-olacak-2024-yili-resmi-tatil-gunleri-3645225...
# Fetched external CSS from https://www.haberturk.com/css/desktop/style.css?v=250
# Found internal CSS within <style> tags 1
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <i> tag
# Found inline CSS in <div> tag
# Found inline CSS in <div> tag
# Found inline CSS in <section> tag
# Found inline CSS in <div> tag
# Found inline CSS in <iframe> tag
# (536/536) Successfully fetched CSS from https://www.haberturk.com/2024-yilinda-kac-gun-tatil-olacak-2024-yili-resmi-tatil-gunleri-3645225
# Logging complete. HTML and JSON reports have been saved.
