# %%
import json
import requests
from urllib.parse import urljoin, urlparse, urlunparse
from bs4 import BeautifulSoup
import urllib3
import re
import time
from requests.exceptions import RequestException, ConnectionError, Timeout
import socket
import logging

# suppress warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# load urls from a json file
def load_urls(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data['unique_urls']

# load common words from a json file
def load_common_words(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return list(data.keys())[:10]
    except KeyError:
        print("Error: Could not load common words from the JSON file.")
        return []

# load url headings from a json file
def load_url_headings(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except UnicodeDecodeError:
        with open(json_file, 'r', encoding='latin1') as file:
            data = json.load(file)
        return data

# load image data from a json file
def load_image_data(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except UnicodeDecodeError:
        with open(json_file, 'r', encoding='latin1') as file:
            data = json.load(file)
        return data

# load script data from a json file
def load_scripts(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except UnicodeDecodeError:
        with open(json_file, 'r', encoding='latin1') as file:
            data = json.load(file)
        return data

# load css files from a json file
def load_css_files(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# load pagesize and loadtime data from a json file
def load_page_size_data(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# check if the website has a title and how many characters it is
def check_title(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        title_tag = soup.find('title')
        if title_tag:
            title = title_tag.text
            title_length = len(title)
            if title_length < 20:
                title_status = 'too short'
            elif title_length > 75:
                title_status = 'too long'
            else:
                title_status = 'valid'
            return True, title_length, title_status, title
        return False, 0, 'no title', ''
    except requests.exceptions.RequestException as e:
        print(f"error fetching title data {url}: {e}")
        return False, 0, 'error', ''

# check if the website has a description and how many characters it is
def check_description(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        description_tag = soup.find('meta', attrs={'name': 'description'})
        if description_tag and 'content' in description_tag.attrs:
            description = description_tag['content']
            description_length = len(description)
            if description_length < 50:
                description_status = 'too short'
            elif description_length > 160:
                description_status = 'too long'
            else:
                description_status = 'valid'
            return True, description_length, description_status, description
        return False, 0, 'no description', ''
    except requests.exceptions.RequestException as e:
        print(f"error fetching description data {url}: {e}")
        return False, 0, 'error', ''

# check if the title or description contains any of the common words
def check_common_words(title, description, common_words):
    title_words = set(title.lower().split())
    description_words = set(description.lower().split())
    for word in common_words:
        if word in title_words or word in description_words:
            return True
    return False

# check if the h1 tag has content
def check_h1_content(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        h1_tags = soup.find_all('h1')
        for h1 in h1_tags:
            if h1.text.strip():  # check if there is content inside the h1 tag
                return True
        return False
    except requests.exceptions.RequestException as e:
        print(f"error fetching h1 data {url}: {e}")
        return False

# check if the h2 tag has content
def check_h2_content(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        h2_tags = soup.find_all('h2')
        for h2 in h2_tags:
            if h2.text.strip():  # check if there is content inside the h2 tag
                return True
        return False
    except requests.exceptions.RequestException as e:
        print(f"error fetching h2 data {url}: {e}")
        return False

# check if all images have alt text
def check_images_alt_text(url, image_data):
    images = image_data.get(url, [])
    for image in images:
        if not image['alt'].strip():  # check if alt text is empty
            return False
    return True

# check if the website has a canonical tag
def check_canonical_tag(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        canonical_tag = soup.find('link', rel='canonical')
        return canonical_tag is not None
    except requests.exceptions.RequestException as e:
        print(f"error fetching canonical tag data {url}: {e}")
        return False

# check if the website has a noindex header or meta tag
# returns True if there is no noindex tag which is intended
# as there shouldnt be any
def check_noindex_tag(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        meta_noindex = soup.find('meta', attrs={'name': 'robots', 'content': 'noindex'})
        header_noindex = response.headers.get('X-Robots-Tag') == 'noindex'
        return meta_noindex is None and not header_noindex
    except requests.exceptions.RequestException as e:
        print(f"error fetching noindex data {url}: {e}")
        return False

# check if the www and non-www versions of the url go to the same site
def check_www_and_non_www(url):
    try:
        parsed_url = urlparse(url)
        if parsed_url.hostname.startswith('www.'):
            non_www_url = urlunparse(parsed_url._replace(netloc=parsed_url.hostname[4:]))
        else:
            non_www_url = urlunparse(parsed_url._replace(netloc='www.' + parsed_url.hostname))
        
        www_response = requests.get(url, verify=False, allow_redirects=True)
        non_www_response = requests.get(non_www_url, verify=False, allow_redirects=True)
        
        return www_response.url == non_www_response.url
    except requests.exceptions.RequestException as e:
        # print(f"error fetching www data {url} or {non_www_url}: {e}") ///
        # if they dont redirect it doesnt load the site, so it will appear as error
        # so we dont log errors here ///
        return False

# check if the website has a robots.txt file
def check_robots_txt(url):
    try:
        parsed_url = urlparse(url)
        robots_url = urlunparse((parsed_url.scheme, parsed_url.netloc, '/robots.txt', '', '', ''))
        response = requests.get(robots_url, verify=False)
        return response.status_code == 200
    except requests.exceptions.RequestException as e:
        print(f"error fetching robots txt data {robots_url}: {e}")
        return False

# check if the website has Open Graph meta tags
def check_open_graph_tags(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        og_tags = soup.find_all('meta', property=lambda x: x and x.startswith('og:'))
        return len(og_tags) > 0
    except requests.exceptions.RequestException as e:
        print(f"error fetching open graph data {url}: {e}")
        return False

# check if the website has structured data
def check_structured_data(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        json_ld = soup.find_all('script', type='application/ld+json')
        microdata = soup.find_all(attrs={"itemscope": True})
        rdfa = soup.find_all(attrs={"typeof": True})
        return len(json_ld) > 0 or len(microdata) > 0 or len(rdfa) > 0
    except requests.exceptions.RequestException as e:
        print(f"error fetching structured data {url}: {e}")
        return False

# check if images have an expires header
def check_images_expires_header(url, image_data):
    try:
        images = image_data.get(url, [])
        for image in images:
            response = requests.head(image['url'], verify=False)
            if 'Expires' not in response.headers:
                return False
        return True
    except requests.exceptions.RequestException as e:
        print(f"error fetching image {image['url']}: {e}")
        return False

# check if all javascript files are minified
def check_js_minified(url, scripts_data):
    try:
        scripts = scripts_data.get(url, [])
        for script_url in scripts:
            if not script_url.endswith('.js'):
                continue
            script_response = requests.get(script_url, verify=False)
            script_content = script_response.text
            if len(re.findall(r'\n', script_content)) > 20:  # check for minification
                return False
        return True
    except requests.exceptions.RequestException as e:
        print(f"error fetching javascript {script_url}: {e}")
        return False

# check if css files are minified
def check_css_minified(url, css_data):
    css_files = css_data.get(url, [])
    for css_content in css_files:
        if len(css_content.strip()) == 0:
            continue
        # calculate the percentage of whitespace characters
        whitespace_percentage = sum(1 for c in css_content if c in (' ', '\n', '\t', '\r')) / len(css_content)
        if whitespace_percentage > 0.1:  # more than 10% whitespace
            return False
    return True

# check if number of requests is too much
def check_number_of_requests(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        
        # find all resource tags
        img_tags = soup.find_all('img')
        script_tags = soup.find_all('script')
        link_tags = soup.find_all('link', rel='stylesheet')
        
        # extract URLs
        urls = [tag.get('src') for tag in img_tags + script_tags if tag.get('src')]
        urls += [tag.get('href') for tag in link_tags if tag.get('href')]
        
        # count total and unique requests
        total_requests = len(urls)
        unique_requests = len(set(urls))
        
        # determine the status based on the number of total requests
        if total_requests > 50:
            return False, total_requests, unique_requests
        else:
            return True, total_requests, unique_requests
    except requests.exceptions.RequestException as e:
        print(f"error fetching number of requests {url}: {e}")
        return False, 0, 0

# check if page size is too big
def check_page_size(url, page_size_data):
    for page in page_size_data:
        if page['url'] == url:
            size_bytes = page['size']
            if size_bytes is None:
                return False, 'unknown size'
            size_kb = size_bytes / 1024  # convert bytes to kb
            if size_kb <= 50:
                return True, size_kb
            else:
                return False, size_kb
    return False, 'not found'

# check if load time is too long (>2 seconds)
def check_load_time(url, page_size_data):
    for page in page_size_data:
        if page['url'] == url:
            load_time = page['load_time']
            if load_time is None:
                return False, 'unknown load time'
            elif load_time <= 2:
                return True, load_time
            else:
                return False, load_time
    return False, 'not found'

# check if response time is too long (>200ms)
def check_response_time(url):
    try:
        start_time = time.time()
        response = requests.get(url, verify=False)  # disable SSL verification
        response_time = time.time() - start_time
        if response_time <= 0.2:
            return True, response_time
        else:
            return False, response_time
    except requests.exceptions.RequestException as e:
        print(f"error fetching {url}: {e}")
        return False, 'error'

# check if directory listing is disabled
def check_directory_listing(url):
    try:
        # Attempt to access a directory by appending a slash to the URL
        if not url.endswith('/'):
            url += '/'
        response = requests.get(url, verify=False)  # disable SSL verification
        
        # Check if the response indicates a directory listing
        if response.status_code == 200 and 'Index of' in response.text:
            return False  # directory listing is enabled
        else:
            return True  # directory listing is disabled
    except requests.exceptions.RequestException as e:
        print(f"error fetching {url}: {e}")
        return 'error'

# main function to load urls and perform seo checks
def main():
    base_url = "https://www.haberturk.com"
    urls = load_urls('urls.json')
    common_words = load_common_words('text_common_words.json')
    url_headings = load_url_headings('url_headings.json')
    image_data = load_image_data('image_data.json')
    scripts_data = load_scripts('scripts.json')
    css_data = load_css_files('css_files.json')
    page_size_data = load_page_size_data('pagesize_load_time.json')
    results = []

    for index, relative_url in enumerate(urls):
        full_url = urljoin(base_url, relative_url)
        try:
            has_title, title_length, title_status, title = check_title(full_url)
            has_description, description_length, description_status, description = check_description(full_url)
            common_words_status = check_common_words(title, description, common_words)
            h1_content_status = check_h1_content(full_url)
            h2_content_status = check_h2_content(full_url)
            images_alt_text_status = check_images_alt_text(full_url, image_data)
            canonical_tag_status = check_canonical_tag(full_url)
            noindex_tag_status = check_noindex_tag(full_url)
            www_non_www_status = check_www_and_non_www(full_url)
            robots_txt_status = check_robots_txt(full_url)
            open_graph_tags_status = check_open_graph_tags(full_url)
            structured_data_status = check_structured_data(full_url)
            images_expires_header_status = check_images_expires_header(full_url, image_data)
            js_minified_status = check_js_minified(full_url, scripts_data)
            css_minified_status = check_css_minified(full_url, css_data)
            number_of_requests_status, total_requests, unique_requests = check_number_of_requests(full_url)
            page_size_status, page_size = check_page_size(full_url, page_size_data)
            load_time_status, load_time = check_load_time(full_url, page_size_data)
            response_time_status, response_time = check_response_time(full_url)
            directory_listing_status = check_directory_listing(full_url)
            

            # print results for the current URL
            print(f"{index + 1}/{len(urls)} - url: {full_url}\n"
                  f"  has title: {has_title}\n"
                  f"  title length: {title_length} characters\n"
                  f"  title status: {title_status}\n"
                  f"  has description: {has_description}\n"
                  f"  description length: {description_length} characters\n"
                  f"  description status: {description_status}\n"
                  f"  common words status: {common_words_status}\n"
                  f"  h1 content status: {h1_content_status}\n"
                  f"  h2 content status: {h2_content_status}\n"
                  f"  images alt text status: {images_alt_text_status}\n"
                  f"  canonical tag status: {canonical_tag_status}\n"
                  f"  noindex tag status: {noindex_tag_status}\n"
                  f"  www and non-www status: {www_non_www_status}\n"
                  f"  robots.txt status: {robots_txt_status}\n"
                  f"  open graph tags status: {open_graph_tags_status}\n"
                  f"  structured data status: {structured_data_status}\n"
                  f"  images expires header status: {images_expires_header_status}\n"
                  f"  js minified status: {js_minified_status}\n"
                  f"  css minified status: {css_minified_status}\n"
                  f"  number of requests status: {number_of_requests_status} (total requests: {total_requests}, unique requests: {unique_requests})\n"
                  f"  page size status: {page_size_status} (size: {page_size} KB)\n"
                  f"  load time status: {load_time_status} (load time: {load_time} seconds)\n"
                  f"  response time status: {response_time_status} (response time: {response_time:.4f} seconds)\n"
                  f"  directory listing disabled status: {directory_listing_status}\n")
            
            # store results for seo score calculation
            results.append({
                'url': full_url,
                'has_title': has_title,
                'title_length': title_length,
                'title_status': title_status,
                'has_description': has_description,
                'description_length': description_length,
                'description_status': description_status,
                'common_words_status': common_words_status,
                'h1_content_status': h1_content_status,
                'h2_content_status': h2_content_status,
                'images_alt_text_status': images_alt_text_status,
                'canonical_tag_status': canonical_tag_status,
                'noindex_tag_status': noindex_tag_status,
                'www_non_www_status': www_non_www_status,
                'robots_txt_status': robots_txt_status,
                'open_graph_tags_status': open_graph_tags_status,
                'structured_data_status': structured_data_status,
                'images_expires_header_status': images_expires_header_status,
                'js_minified_status': js_minified_status,
                'css_minified_status': css_minified_status,
                'number_of_requests_status': number_of_requests_status,
                'total_requests': total_requests,
                'unique_requests': unique_requests,
                'page_size_status': page_size_status,
                'page_size': page_size,
                'load_time_status': load_time_status,
                'load_time': load_time,
                'response_time_status': response_time_status,
                'response_time': response_time,
                'directory_listing_status': directory_listing_status,
                # more will be added
            })

        except (requests.exceptions.RequestException, requests.exceptions.ConnectionError, requests.exceptions.Timeout, socket.gaierror):
            results.append({
                'url': full_url,
                'has_title': False,
                'title_length': 0,
                'title_status': 'error',
                'has_description': False,
                'description_length': 0,
                'description_status': 'error',
                'common_words_status': False,
                'h1_content_status': False,
                'h2_content_status': False,
                'images_alt_text_status': False,
                'canonical_tag_status': False,
                'noindex_tag_status': False,
                'www_non_www_status': False,
                'robots_txt_status': False,
                'open_graph_tags_status': False,
                'structured_data_status': False,
                'images_expires_header_status': False,
                'js_minified_status': False,
                'css_minified_status': False,
                'number_of_requests_status': False,
                'total_requests': 0,
                'unique_requests': 0,
                'page_size_status': False,
                'page_size': 0,
                'load_time_status': False,
                'load_time': 0,
                'response_time_status': False,
                'response_time': 0,
                'directory_listing_status': False,    
                # more will be added
            })

        print("\n")  # add space between the results of each URL
    
    # calculate seo score
    for result in results:
        score = (1 if result['title_status'] == 'valid' else 0) + \
                (1 if result['description_status'] == 'valid' else 0) + \
                (1 if result['common_words_status'] else 0) + \
                (1 if result['h1_content_status'] else 0) + \
                (1 if result['h2_content_status'] else 0) + \
                (1 if result['images_alt_text_status'] else 0) + \
                (1 if result['canonical_tag_status'] else 0) + \
                (1 if result['noindex_tag_status'] else 0) + \
                (1 if result['www_non_www_status'] else 0) + \
                (1 if result['robots_txt_status'] else 0) + \
                (1 if result['open_graph_tags_status'] else 0) + \
                (1 if result['structured_data_status'] else 0) + \
                (1 if result['images_expires_header_status'] else 0) + \
                (1 if result['js_minified_status'] else 0) + \
                (1 if result['css_minified_status'] else 0) + \
                (1 if result['number_of_requests_status'] else 0) + \
                (1 if result['page_size_status'] else 0) + \
                (1 if result['load_time_status'] else 0) + \
                (1 if result['response_time_status'] else 0) + \
                (1 if result['directory_listing_status'] else 0)
                # more will be added
        seo_score = (score / 20) * 100  # to calculate the score out of 100%
        print(f"url: {result['url']}, seo score: {seo_score:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# 1/536 - url: https://www.haberturk.com/images/common/manifest/180x180.png
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 3.447265625 KB)
#   load time status: True (load time: 0.06297588348388672 seconds)
#   response time status: True (response time: 0.0513 seconds)
#   directory listing disabled status: True
#
#
#
# 2/536 - url: https://www.haberturk.com/images/common/favicon/32x32.png
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.8916015625 KB)
#   load time status: True (load time: 0.011125564575195312 seconds)
#   response time status: True (response time: 0.0471 seconds)
#   directory listing disabled status: True
#
#
#
# 3/536 - url: https://www.haberturk.com/images/common/favicon/16x16.png
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.5166015625 KB)
#   load time status: True (load time: 0.05585002899169922 seconds)
#   response time status: True (response time: 0.0455 seconds)
#   directory listing disabled status: True
#
#
#
# 4/536 - url: https://www.haberturk.com/images/common/favicon/favicon.ico?v=001
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 3.447265625 KB)
#   load time status: True (load time: 0.010546445846557617 seconds)
#   response time status: True (response time: 0.0558 seconds)
#   directory listing disabled status: True
#
#
#
# 5/536 - url: https://www.haberturk.com/manifest.webmanifest
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.7265625 KB)
#   load time status: True (load time: 0.008000373840332031 seconds)
#   response time status: True (response time: 0.0522 seconds)
#   directory listing disabled status: True
#
#
#
# 6/536 - url: https://im.haberturk.com
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.017578125 KB)
#   load time status: True (load time: 0.06183457374572754 seconds)
#   response time status: True (response time: 0.0461 seconds)
#   directory listing disabled status: True
#
#
#
# 7/536 - url: https://adsp.haberturk.com
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.1416015625 KB)
#   load time status: True (load time: 0.08223843574523926 seconds)
#   response time status: True (response time: 0.0439 seconds)
#   directory listing disabled status: True
#
#
#
# 8/536 - url: https://im.hthayat.com
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: False (size: unknown size KB)
#   load time status: False (load time: 2.7176754474639893 seconds)
#   response time status: True (response time: 0.0440 seconds)
#   directory listing disabled status: True
#
#
#
# 9/536 - url: https://geoim.bloomberght.com
#   has title: True
#   title length: 13 characters
#   title status: too short
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: True
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.158203125 KB)
#   load time status: True (load time: 0.06482839584350586 seconds)
#   response time status: True (response time: 0.0479 seconds)
#   directory listing disabled status: True
#
#
#
# 10/536 - url: https://im.showtv.com.tr
#   has title: True
#   title length: 13 characters
#   title status: too short
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: True
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.158203125 KB)
#   load time status: True (load time: 0.14375901222229004 seconds)
#   response time status: True (response time: 0.0517 seconds)
#   directory listing disabled status: True
#
#
#
# 11/536 - url: https://mo.ciner.com.tr
#   has title: True
#   title length: 13 characters
#   title status: too short
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: True
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.158203125 KB)
#   load time status: True (load time: 0.06681656837463379 seconds)
#   response time status: True (response time: 0.0845 seconds)
#   directory listing disabled status: True
#
#
#
# 12/536 - url: https://static.criteo.net
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 0.0419921875 KB)
#   load time status: True (load time: 0.182450532913208 seconds)
#   response time status: True (response time: 0.1965 seconds)
#   directory listing disabled status: True
#
#
#
# 13/536 - url: https://pagead2.googlesyndication.com
#   has title: True
#   title length: 24 characters
#   title status: valid
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 1.5244140625 KB)
#   load time status: True (load time: 0.20492029190063477 seconds)
#   response time status: False (response time: 0.2277 seconds)
#   directory listing disabled status: True
#
#
#
# error fetching image data:image/png;base64,...: No connection adapters were found for 'data:image/png;base64,...'
# 14/536 - url: https://www.google.com
#   has title: True
#   title length: 6 characters
#   title status: too short
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: True
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 3, unique requests: 3)
#   page size status: True (size: 20.1025390625 KB)
#   load time status: True (load time: 0.8387300968170166 seconds)
#   response time status: False (response time: 0.3167 seconds)
#   directory listing disabled status: True
#
#
#
# 15/536 - url: https://www.google-analytics.com
#   has title: True
#   title length: 64 characters
#   title status: valid
#   has description: True
#   description length: 215 characters
#   description status: too long
#   common words status: False
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: True
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 20, unique requests: 20)
#   page size status: False (size: 115.638671875 KB)
#   load time status: True (load time: 0.5896804332733154 seconds)
#   response time status: False (response time: 0.5279 seconds)
#   directory listing disabled status: True
#
#
#
# 16/536 - url: https://www.googletagmanager.com
#   has title: True
#   title length: 24 characters
#   title status: valid
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 1.5185546875 KB)
#   load time status: True (load time: 1.1578607559204102 seconds)
#   response time status: True (response time: 0.1486 seconds)
#   directory listing disabled status: True
#
#
#
# 17/536 - url: https://www.googletagservices.com
#   has title: True
#   title length: 24 characters
#   title status: valid
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 1.5244140625 KB)
#   load time status: True (load time: 0.18101191520690918 seconds)
#   response time status: False (response time: 0.2042 seconds)
#   directory listing disabled status: True
#
#
#
# 18/536 - url: https://securepubads.g.doubleclick.net
#   has title: True
#   title length: 24 characters
#   title status: valid
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 1.5244140625 KB)
#   load time status: True (load time: 0.22206449508666992 seconds)
#   response time status: False (response time: 0.3301 seconds)
#   directory listing disabled status: True
#
#
#
# 19/536 - url: https://www.haberturk.com
#   has title: True
#   title length: 68 characters
#   title status: valid
#   has description: True
#   description length: 182 characters
#   description status: too long
#   common words status: True
#   h1 content status: False
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: False (total requests: 411, unique requests: 11)
#   page size status: False (size: 507.7041015625 KB)
#   load time status: True (load time: 0.7521300315856934 seconds)
#   response time status: True (response time: 0.0585 seconds)
#   directory listing disabled status: True
#
#
#
# 20/536 - url: https://m.haberturk.com
#   has title: True
#   title length: 68 characters
#   title status: valid
#   has description: True
#   description length: 182 characters
#   description status: too long
#   common words status: True
#   h1 content status: False
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: False (total requests: 355, unique requests: 10)
#   page size status: False (size: 490.31640625 KB)
#   load time status: True (load time: 0.779207706451416 seconds)
#   response time status: True (response time: 0.0687 seconds)
#   directory listing disabled status: True
#
#
#
# 21/536 - url: https://www.haberturk.com/css/desktop/style.css?v=252
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: False
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: False (size: 134.0439453125 KB)
#   load time status: True (load time: 0.06385922431945801 seconds)
#   response time status: True (response time: 0.0652 seconds)
#   directory listing disabled status: True
#
#
#
# 22/536 - url: https://im.haberturk.com/l/2024/06/19/ver1718799771/3696380/jpg/320x640
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: False (size: 58.3486328125 KB)
#   load time status: True (load time: 0.026936769485473633 seconds)
#   response time status: True (response time: 0.0689 seconds)
#   directory listing disabled status: True
#
#
#
# 23/536 - url: https://im.haberturk.com/l/2024/06/20/ver1718831744/3696460/jpg/320x640
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: True (size: 49.3955078125 KB)
#   load time status: True (load time: 0.13942575454711914 seconds)
#   response time status: True (response time: 0.0674 seconds)
#   directory listing disabled status: True
#
#
#
# 24/536 - url: https://im.haberturk.com/l/2024/06/20/ver1718863122/3696489_manset/jpg/640x640
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: False (size: 129.6220703125 KB)
#   load time status: True (load time: 0.02588057518005371 seconds)
#   response time status: True (response time: 0.0703 seconds)
#   directory listing disabled status: True
#
#
#
# 25/536 - url: https://im.haberturk.com/l/2024/06/20/ver1718858199/3696483_manset/jpg/640x640
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: False
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: False
#   robots.txt status: False
#   open graph tags status: False
#   structured data status: False
#   images expires header status: False
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 0, unique requests: 0)
#   page size status: False (size: 81.1806640625 KB)
#   load time status: True (load time: 0.028922319412231445 seconds)
#   response time status: True (response time: 0.0890 seconds)
#   directory listing disabled status: True
#
#
#
# 26/536 - url: https://www.haberturk.com/adscbg/cbglout.js
#   has title: False
#   title length: 0 characters
#   title status: no title
#   has description: False
#   description length: 0 characters
#   description status: no description
#   common words status: False
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: False
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: False
#   structured data status: True
#   images expires header status: True
#   js minified status: True
#   css minified status: True
#   number of requests status: True (total requests: 1, unique requests: 1)
#   page size status: False (size: 70.330078125 KB)
#   load time status: True (load time: 0.04742884635925293 seconds)
#   response time status: True (response time: 0.0484 seconds)
#   directory listing disabled status: True
#
#
#
# 27/536 - url: https://www.haberturk.com/ekonomi
#   has title: True
#   title length: 68 characters
#   title status: valid
#   has description: True
#   description length: 176 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: False (total requests: 110, unique requests: 13)
#   page size status: False (size: 221.857421875 KB)
#   load time status: True (load time: 0.7482681274414062 seconds)
#   response time status: True (response time: 0.0585 seconds)
#   directory listing disabled status: True
#
#
#
# 28/536 - url: https://www.haberturk.com/ekonomi/altin
#   has title: True
#   title length: 78 characters
#   title status: too long
#   has description: True
#   description length: 241 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 32, unique requests: 12)
#   page size status: False (size: 90.431640625 KB)
#   load time status: True (load time: 0.8314106464385986 seconds)
#   response time status: True (response time: 0.0540 seconds)
#   directory listing disabled status: True
#
#
#
# 29/536 - url: https://www.haberturk.com/ekonomi/piyasa/88-dolar
#   has title: True
#   title length: 78 characters
#   title status: too long
#   has description: True
#   description length: 242 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 30, unique requests: 12)
#   page size status: False (size: 114.5380859375 KB)
#   load time status: True (load time: 1.137727975845337 seconds)
#   response time status: True (response time: 0.0508 seconds)
#   directory listing disabled status: True
#
#
#
# 30/536 - url: https://www.haberturk.com/ekonomi/piyasa/89-euro
#   has title: True
#   title length: 76 characters
#   title status: too long
#   has description: True
#   description length: 230 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 30, unique requests: 12)
#   page size status: False (size: 114.5654296875 KB)
#   load time status: True (load time: 0.5777058601379395 seconds)
#   response time status: True (response time: 0.0621 seconds)
#   directory listing disabled status: True
#
#
#
# 31/536 - url: https://www.haberturk.com/ekonomi/altin/610-gram-altin
#   has title: True
#   title length: 76 characters
#   title status: too long
#   has description: True
#   description length: 253 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 32, unique requests: 12)
#   page size status: False (size: 82.810546875 KB)
#   load time status: True (load time: 0.5648963451385498 seconds)
#   response time status: True (response time: 0.0729 seconds)
#   directory listing disabled status: True
#
#
#
# 32/536 - url: https://www.haberturk.com/ekonomi/piyasa/1947-faiz
#   has title: True
#   title length: 55 characters
#   title status: valid
#   has description: True
#   description length: 85 characters
#   description status: valid
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 19, unique requests: 12)
#   page size status: False (size: 72.259765625 KB)
#   load time status: True (load time: 0.8576922416687012 seconds)
#   response time status: True (response time: 0.0469 seconds)
#   directory listing disabled status: True
#
#
#
# 33/536 - url: https://www.haberturk.com/ekonomi/piyasa/2211-bitcoin
#   has title: True
#   title length: 92 characters
#   title status: too long
#   has description: True
#   description length: 196 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: False
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 21, unique requests: 13)
#   page size status: False (size: 67.4052734375 KB)
#   load time status: True (load time: 0.5079035758972168 seconds)
#   response time status: True (response time: 0.0522 seconds)
#   directory listing disabled status: True
#
#
#
# 34/536 - url: https://www.haberturk.com/ekonomi/borsa
#   has title: True
#   title length: 69 characters
#   title status: valid
#   has description: True
#   description length: 162 characters
#   description status: too long
#   common words status: True
#   h1 content status: True
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 19, unique requests: 12)
#   page size status: False (size: 141.8232421875 KB)
#   load time status: True (load time: 0.5857820510864258 seconds)
#   response time status: True (response time: 0.0554 seconds)
#   directory listing disabled status: True
#
#
#
# 35/536 - url: https://www.haberturk.com/canliyayin
#   has title: True
#   title length: 29 characters
#   title status: valid
#   has description: True
#   description length: 252 characters
#   description status: too long
#   common words status: False
#   h1 content status: False
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 40, unique requests: 16)
#   page size status: False (size: 68.08203125 KB)
#   load time status: True (load time: 1.1991872787475586 seconds)
#   response time status: True (response time: 0.0522 seconds)
#   directory listing disabled status: True
#
#
#
# 36/536 - url: https://www.haberturk.com/
#   has title: True
#   title length: 68 characters
#   title status: valid
#   has description: True
#   description length: 182 characters
#   description status: too long
#   common words status: True
#   h1 content status: False
#   h2 content status: True
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: False (total requests: 411, unique requests: 11)
#   page size status: False (size: 507.826171875 KB)
#   load time status: True (load time: 0.7562196254730225 seconds)
#   response time status: True (response time: 0.0705 seconds)
#   directory listing disabled status: True
#
#
#
# 37/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Adana/LTAG
#   has title: True
#   title length: 56 characters
#   title status: valid
#   has description: True
#   description length: 157 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5166015625 KB)
#   load time status: True (load time: 1.0082616806030273 seconds)
#   response time status: True (response time: 0.0652 seconds)
#   directory listing disabled status: True
#
#
#
# 38/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Adiyaman/LTDY
#   has title: True
#   title length: 59 characters
#   title status: valid
#   has description: True
#   description length: 160 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5166015625 KB)
#   load time status: True (load time: 0.5674545764923096 seconds)
#   response time status: True (response time: 0.0854 seconds)
#   directory listing disabled status: True
#
#
#
# 39/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Afyon/LTAF
#   has title: True
#   title length: 56 characters
#   title status: valid
#   has description: True
#   description length: 157 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5087890625 KB)
#   load time status: True (load time: 0.5109639167785645 seconds)
#   response time status: True (response time: 0.0572 seconds)
#   directory listing disabled status: True
#
#
#
# 40/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Agri/LTCB
#   has title: True
#   title length: 55 characters
#   title status: valid
#   has description: True
#   description length: 156 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5927734375 KB)
#   load time status: True (load time: 0.5171644687652588 seconds)
#   response time status: True (response time: 0.0910 seconds)
#   directory listing disabled status: True
#
#
#
# 41/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Amasya/LTT3
#   has title: True
#   title length: 57 characters
#   title status: valid
#   has description: True
#   description length: 158 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5263671875 KB)
#   load time status: True (load time: 0.8163893222808838 seconds)
#   response time status: True (response time: 0.0578 seconds)
#   directory listing disabled status: True
#
#
#
# 42/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Ankara/LTAD
#   has title: True
#   title length: 57 characters
#   title status: valid
#   has description: True
#   description length: 158 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5263671875 KB)
#   load time status: True (load time: 0.5730934143066406 seconds)
#   response time status: True (response time: 0.1003 seconds)
#   directory listing disabled status: True
#
#
#
# 43/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Antalya/TU0199
#   has title: True
#   title length: 58 characters
#   title status: valid
#   has description: True
#   description length: 159 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.509765625 KB)
#   load time status: True (load time: 0.583714485168457 seconds)
#   response time status: True (response time: 0.0561 seconds)
#   directory listing disabled status: True
#
#
#
# 44/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Artvin/LTAT
#   has title: True
#   title length: 57 characters
#   title status: valid
#   has description: True
#   description length: 158 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5947265625 KB)
#   load time status: True (load time: 0.532489538192749 seconds)
#   response time status: True (response time: 0.0690 seconds)
#   directory listing disabled status: True
#
#
#
# 45/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Aydin/LT03
#   has title: True
#   title length: 56 characters
#   title status: valid
#   has description: True
#   description length: 157 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.4775390625 KB)
#   load time status: True (load time: 1.1407957077026367 seconds)
#   response time status: True (response time: 0.1212 seconds)
#   directory listing disabled status: True
#
#
#
# 46/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Balikesir/LTBF
#   has title: True
#   title length: 60 characters
#   title status: valid
#   has description: True
#   description length: 161 characters
#   description status: too long
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5263671875 KB)
#   load time status: True (load time: 0.5633323192596436 seconds)
#   response time status: True (response time: 0.0570 seconds)
#   directory listing disabled status: True
#
#
#
# 47/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Bilecik/LTKY
#   has title: True
#   title length: 58 characters
#   title status: valid
#   has description: True
#   description length: 159 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5078125 KB)
#   load time status: True (load time: 0.881030797958374 seconds)
#   response time status: True (response time: 0.0635 seconds)
#   directory listing disabled status: True
#
#
#
# 48/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Bingol/LTT5
#   has title: True
#   title length: 57 characters
#   title status: valid
#   has description: True
#   description length: 158 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.6171875 KB)
#   load time status: True (load time: 1.1129088401794434 seconds)
#   response time status: True (response time: 0.0573 seconds)
#   directory listing disabled status: True
#
#
#
# 49/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Bitlis/LT07
#   has title: True
#   title length: 57 characters
#   title status: valid
#   has description: True
#   description length: 158 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5751953125 KB)
#   load time status: True (load time: 0.907611608505249 seconds)
#   response time status: True (response time: 0.0581 seconds)
#   directory listing disabled status: True
#
#
#
# 50/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Bolu/LTT1
#   has title: True
#   title length: 55 characters
#   title status: valid
#   has description: True
#   description length: 156 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.5 KB)
#   load time status: True (load time: 1.002007246017456 seconds)
#   response time status: True (response time: 0.0552 seconds)
#   directory listing disabled status: True
#
#
#
# 51/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Burdur/LT08
#   has title: True
#   title length: 57 characters
#   title status: valid
#   has description: True
#   description length: 158 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.501953125 KB)
#   load time status: True (load time: 1.0705161094665527 seconds)
#   response time status: True (response time: 0.0652 seconds)
#   directory listing disabled status: True
#
#
#
# 52/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Bursa/LTBU
#   has title: True
#   title length: 56 characters
#   title status: valid
#   has description: True
#   description length: 157 characters
#   description status: valid
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
#   page size status: False (size: 68.4580078125 KB)
#   load time status: True (load time: 1.0467915534973145 seconds)
#   response time status: True (response time: 0.0612 seconds)
#   directory listing disabled status: True
#
#
#
# 53/536 - url: https://www.haberturk.com/havadurumu/Turkiye-TR/Canakkale/LTBH
#   has title: True
#   title length: 60 characters
#   title status: valid
#   has description: True
#   description length: 161 characters
#   description status: too long
#   common words status: True
#   h1 content status: False
#   h2 content status: False
#   images alt text status: True
#   canonical tag status: True
#   noindex tag status: True
#   www and non-www status: True
#   robots.txt status: True
#   open graph tags status: True
#   structured data status: True
#   images expires header status: False
#   js minified status: False
#   css minified status: True
#   number of requests status: True (total requests: 16, unique requests: 11)
# ...
# url: https://www.haberturk.com/4-silahla-kursun-yagmuru-guncel-haberler-3696221, seo score: 75.00%
# url: https://www.haberturk.com/kalp-krizi-degil-yorgun-mermi-cikti-guncel-haberler-3695976, seo score: 70.00%
# url: https://www.haberturk.com/anaokulunun-camini-kirdi-guncel-haberler-3695627, seo score: 75.00%
# url: https://www.haberturk.com/alkollu-ve-ofkeli-guncel-haberler-3695378, seo score: 75.00%
# url: https://www.haberturk.com/cekcekcilerin-bicakli-kavgasi-guncel-haberler-3695036, seo score: 75.00%
# url: https://www.haberturk.com/hali-cinayetinde-kahreden-goruntu-guncel-haberler-3694684, seo score: 70.00%
# url: https://www.haberturk.com/kursunlayip-onunde-nobet-tuttu-guncel-haberler-3694352, seo score: 75.00%
# url: https://www.haberturk.com/zil-caldi-kapiyi-acti-olduruldu-guncel-haberler-3694014, seo score: 75.00%
# url: https://www.haberturk.com/halidaki-vahsetin-sirri-guncel-haberler-3693602, seo score: 70.00%
# url: https://www.haberturk.com/ogretmene-kanli-infaz-guncel-haberler-3693094, seo score: 75.00%
# url: https://www.haberturk.com/kogus-arkadasligi-cinayetle-bitti-guncel-haberler-3692745, seo score: 70.00%
# url: https://www.haberturk.com/kiz-meselesi-cinayeti-guncel-haberler-3692397, seo score: 75.00%
# url: https://www.haberturk.com/eski-sevgilisi-oldurdu-guncel-haberler-3691125, seo score: 75.00%
# url: https://www.haberturk.com/annesi-ile-babasini-oldurdu-guncel-haberler-3690806, seo score: 75.00%
# url: https://www.haberturk.com/oyun-salonunda-cinayet-guncel-haberler-3690448, seo score: 75.00%
