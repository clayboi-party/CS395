# %%
import json
import requests
from urllib.parse import urljoin, urlparse, urlunparse
from bs4 import BeautifulSoup
import urllib3
import re
import time
from requests.exceptions import RequestException, ConnectionError, Timeout
import socket
import logging

# suppress warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

API_KEY = 'AIzaSyAA08ejUlVk8RW2mwNOc218-09VJO95v5k'

# load urls from a json file
def load_urls(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data['unique_urls']

# load keywords from a json file
def load_keywords(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return {item['url']: set(item['keywords'].lower().split(', ')) for item in data}
    except KeyError:
        print("Error: Could not load keywords from the JSON file.")
        return {}


# load url headings from a json file
def load_url_headings(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except UnicodeDecodeError:
        with open(json_file, 'r', encoding='latin1') as file:
            data = json.load(file)
        return data

# load image data from a json file
def load_image_data(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except UnicodeDecodeError:
        with open(json_file, 'r', encoding='latin1') as file:
            data = json.load(file)
        return data

# load script data from a json file
def load_scripts(json_file):
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except UnicodeDecodeError:
        with open(json_file, 'r', encoding='latin1') as file:
            data = json.load(file)
        return data

# load css files from a json file
def load_css_files(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# load pagesize and loadtime data from a json file
def load_page_size_data(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# check if the website has a title and how many characters it is
def check_title(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        title_tag = soup.find('title')
        if title_tag:
            title = title_tag.text
            title_length = len(title)
            if title_length < 20:
                title_status = 'too short'
            elif title_length > 75:
                title_status = 'too long'
            else:
                title_status = 'valid'
            return True, title_length, title_status, title
        return False, 0, 'no title', ''
    except requests.exceptions.RequestException as e:
        print(f"error fetching title data {url}: {e}")
        return False, 0, 'error', ''

# check if the website has a description and how many characters it is
def check_description(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        description_tag = soup.find('meta', attrs={'name': 'description'})
        if description_tag and 'content' in description_tag.attrs:
            description = description_tag['content']
            description_length = len(description)
            if description_length < 50:
                description_status = 'too short'
            elif description_length > 160:
                description_status = 'too long'
            else:
                description_status = 'valid'
            return True, description_length, description_status, description
        return False, 0, 'no description', ''
    except requests.exceptions.RequestException as e:
        print(f"error fetching description data {url}: {e}")
        return False, 0, 'error', ''

# check if the title or description contains any of the keywords
def check_keywords(title, description, keywords):
    title_words = set(title.lower().split())
    description_words = set(description.lower().split())
    for word in keywords:
        if word in title_words or word in description_words:
            return True
    return False


# check if the h1 tag has content
def check_h1_content(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        h1_tags = soup.find_all('h1')
        for h1 in h1_tags:
            if h1.text.strip():  # check if there is content inside the h1 tag
                return True
        return False
    except requests.exceptions.RequestException as e:
        print(f"error fetching h1 data {url}: {e}")
        return False

# check if the h2 tag has content
def check_h2_content(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        h2_tags = soup.find_all('h2')
        for h2 in h2_tags:
            if h2.text.strip():  # check if there is content inside the h2 tag
                return True
        return False
    except requests.exceptions.RequestException as e:
        print(f"error fetching h2 data {url}: {e}")
        return False

# check if all images have alt text
def check_images_alt_text(url, image_data):
    images = image_data.get(url, [])
    for image in images:
        if not image['alt'].strip():  # check if alt text is empty
            return False
    return True

# check if the website has a canonical tag
def check_canonical_tag(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        canonical_tag = soup.find('link', rel='canonical')
        return canonical_tag is not None
    except requests.exceptions.RequestException as e:
        print(f"error fetching canonical tag data {url}: {e}")
        return False

# check if the website has a noindex header or meta tag
# returns True if there is no noindex tag which is intended
# as there shouldnt be any
def check_noindex_tag(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        meta_noindex = soup.find('meta', attrs={'name': 'robots', 'content': 'noindex'})
        header_noindex = response.headers.get('X-Robots-Tag') == 'noindex'
        return meta_noindex is None and not header_noindex
    except requests.exceptions.RequestException as e:
        print(f"error fetching noindex data {url}: {e}")
        return False

# check if the www and non-www versions of the url go to the same site
def check_www_and_non_www(url):
    try:
        parsed_url = urlparse(url)
        if parsed_url.hostname.startswith('www.'):
            non_www_url = urlunparse(parsed_url._replace(netloc=parsed_url.hostname[4:]))
        else:
            non_www_url = urlunparse(parsed_url._replace(netloc='www.' + parsed_url.hostname))
        
        www_response = requests.get(url, verify=False, allow_redirects=True)
        non_www_response = requests.get(non_www_url, verify=False, allow_redirects=True)
        
        return www_response.url == non_www_response.url
    except requests.exceptions.RequestException as e:
        # print(f"error fetching www data {url} or {non_www_url}: {e}") ///
        # if they dont redirect it doesnt load the site, so it will appear as error
        # so we dont log errors here ///
        return False

# check if the website has a robots.txt file
def check_robots_txt(url):
    try:
        parsed_url = urlparse(url)
        robots_url = urlunparse((parsed_url.scheme, parsed_url.netloc, '/robots.txt', '', '', ''))
        response = requests.get(robots_url, verify=False)
        return response.status_code == 200
    except requests.exceptions.RequestException as e:
        print(f"error fetching robots txt data {robots_url}: {e}")
        return False

# check if the website has Open Graph meta tags
def check_open_graph_tags(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        og_tags = soup.find_all('meta', property=lambda x: x and x.startswith('og:'))
        return len(og_tags) > 0
    except requests.exceptions.RequestException as e:
        print(f"error fetching open graph data {url}: {e}")
        return False

# check if the website has structured data
def check_structured_data(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        json_ld = soup.find_all('script', type='application/ld+json')
        microdata = soup.find_all(attrs={"itemscope": True})
        rdfa = soup.find_all(attrs={"typeof": True})
        return len(json_ld) > 0 or len(microdata) > 0 or len(rdfa) > 0
    except requests.exceptions.RequestException as e:
        print(f"error fetching structured data {url}: {e}")
        return False

# check if images have an expires header
def check_images_expires_header(url, image_data):
    try:
        images = image_data.get(url, [])
        for image in images:
            response = requests.head(image['url'], verify=False)
            if 'Expires' not in response.headers:
                return False
        return True
    except requests.exceptions.RequestException as e:
        print(f"error fetching image {image['url']}: {e}")
        return False

# check if all javascript files are minified
def check_js_minified(url, scripts_data):
    try:
        scripts = scripts_data.get(url, [])
        for script_url in scripts:
            if not script_url.endswith('.js'):
                continue
            script_response = requests.get(script_url, verify=False)
            script_content = script_response.text
            if len(re.findall(r'\n', script_content)) > 20:  # check for minification
                return False
        return True
    except requests.exceptions.RequestException as e:
        print(f"error fetching javascript {script_url}: {e}")
        return False

# check if css files are minified
def check_css_minified(url, css_data):
    css_files = css_data.get(url, [])
    for css_content in css_files:
        if len(css_content.strip()) == 0:
            continue
        # calculate the percentage of whitespace characters
        whitespace_percentage = sum(1 for c in css_content if c in (' ', '\n', '\t', '\r')) / len(css_content)
        if whitespace_percentage > 0.1:  # more than 10% whitespace
            return False
    return True

# check if number of requests is too much
def check_number_of_requests(url):
    try:
        response = requests.get(url, verify=False)  # disable ssl verification
        response.encoding = 'utf-8'  # check if url has correct encoding
        content = response.content.decode('utf-8', errors='ignore')  # ignore decoding errors
        soup = BeautifulSoup(content, 'html.parser')
        
        # find all resource tags
        img_tags = soup.find_all('img')
        script_tags = soup.find_all('script')
        link_tags = soup.find_all('link', rel='stylesheet')
        
        # extract URLs
        urls = [tag.get('src') for tag in img_tags + script_tags if tag.get('src')]
        urls += [tag.get('href') for tag in link_tags if tag.get('href')]
        
        # count total and unique requests
        total_requests = len(urls)
        unique_requests = len(set(urls))
        
        # determine the status based on the number of total requests
        if total_requests > 50:
            return False, total_requests, unique_requests
        else:
            return True, total_requests, unique_requests
    except requests.exceptions.RequestException as e:
        print(f"error fetching number of requests {url}: {e}")
        return False, 0, 0

# check if page size is too big
def check_page_size(url, page_size_data):
    for page in page_size_data:
        if page['url'] == url:
            size_bytes = page['size']
            if size_bytes is None:
                return False, 'unknown size'
            size_kb = size_bytes / 1024  # convert bytes to kb
            if size_kb <= 50:
                return True, size_kb
            else:
                return False, size_kb
    return False, 'not found'

# check if load time is too long (>2 seconds)
def check_load_time(url, page_size_data):
    for page in page_size_data:
        if page['url'] == url:
            load_time = page['load_time']
            if load_time is None:
                return False, 'unknown load time'
            elif load_time <= 2:
                return True, load_time
            else:
                return False, load_time
    return False, 'not found'

# check if response time is too long (>200ms)
def check_response_time(url):
    try:
        start_time = time.time()
        response = requests.get(url, verify=False)  # disable SSL verification
        response_time = time.time() - start_time
        if response_time <= 0.2:
            return True, response_time
        else:
            return False, response_time
    except requests.exceptions.RequestException as e:
        print(f"error fetching {url}: {e}")
        return False, 'error'

# check if directory listing is disabled
def check_directory_listing(url):
    try:
        # Attempt to access a directory by appending a slash to the URL
        if not url.endswith('/'):
            url += '/'
        response = requests.get(url, verify=False)  # disable SSL verification
        
        # Check if the response indicates a directory listing
        if response.status_code == 200 and 'Index of' in response.text:
            return False  # directory listing is enabled
        else:
            return True  # directory listing is disabled
    except requests.exceptions.RequestException as e:
        print(f"error fetching {url}: {e}")
        return 'error'

# check if the website is flagged by google safe browsing
def check_google_safe_browsing(url):
    try:
        payload = {
            'client': {
                'clientId': 'yourcompanyname',
                'clientVersion': '1.5.2'
            },
            'threatInfo': {
                'threatTypes': ['MALWARE', 'SOCIAL_ENGINEERING', 'UNWANTED_SOFTWARE', 'POTENTIALLY_HARMFUL_APPLICATION'],
                'platformTypes': ['ANY_PLATFORM'],
                'threatEntryTypes': ['URL'],
                'threatEntries': [
                    {'url': url}
                ]
            }
        }
        headers = {'Content-Type': 'application/json'}
        response = requests.post(f'https://safebrowsing.googleapis.com/v4/threatMatches:find?key={API_KEY}', 
                                 data=json.dumps(payload), headers=headers)
        response_data = response.json()
        
        if 'matches' in response_data:
            return False  # flagged by google safe browsing
        else:
            return True  # not flagged by google safe browsing
    except requests.exceptions.RequestException as e:
        print(f"error fetching {url}: {e}")
        return 'error'

# check if the URL is using HTTPS
def check_https(url):
    if url.startswith('https://'):
        return True
    return False

# main function to load urls and perform seo checks
def main():
    base_url = "https://www.haberturk.com"
    urls = load_urls('urls.json')
    url_keywords = load_keywords('meta_tags_parsed.json')
    url_headings = load_url_headings('url_headings.json')
    image_data = load_image_data('image_data.json')
    scripts_data = load_scripts('scripts.json')
    css_data = load_css_files('css_files.json')
    page_size_data = load_page_size_data('pagesize_load_time.json')
    results = []

    for index, relative_url in enumerate(urls):
        full_url = urljoin(base_url, relative_url)
        try:
            has_title, title_length, title_status, title = check_title(full_url)
            has_description, description_length, description_status, description = check_description(full_url)
            keywords = url_keywords.get(full_url, set())
            keywords_status = check_keywords(title, description, keywords)
            h1_content_status = check_h1_content(full_url)
            h2_content_status = check_h2_content(full_url)
            images_alt_text_status = check_images_alt_text(full_url, image_data)
            canonical_tag_status = check_canonical_tag(full_url)
            noindex_tag_status = check_noindex_tag(full_url)
            www_non_www_status = check_www_and_non_www(full_url)
            robots_txt_status = check_robots_txt(full_url)
            open_graph_tags_status = check_open_graph_tags(full_url)
            structured_data_status = check_structured_data(full_url)
            images_expires_header_status = check_images_expires_header(full_url, image_data)
            js_minified_status = check_js_minified(full_url, scripts_data)
            css_minified_status = check_css_minified(full_url, css_data)
            number_of_requests_status, total_requests, unique_requests = check_number_of_requests(full_url)
            page_size_status, page_size = check_page_size(full_url, page_size_data)
            load_time_status, load_time = check_load_time(full_url, page_size_data)
            response_time_status, response_time = check_response_time(full_url)
            directory_listing_status = check_directory_listing(full_url)
            google_safe_browsing_status = check_google_safe_browsing(full_url)
            https_status = check_https(full_url)

            # store results for seo score calculation
            result = {
                'url': full_url,
                'has_title': has_title,
                'title_length': title_length,
                'title_status': title_status,
                'title': title,
                'has_description': has_description,
                'description_length': description_length,
                'description_status': description_status,
                'description': description,
                'keywords_status': keywords_status,
                'h1_content_status': h1_content_status,
                'h2_content_status': h2_content_status,
                'images_alt_text_status': images_alt_text_status,
                'canonical_tag_status': canonical_tag_status,
                'noindex_tag_status': noindex_tag_status,
                'www_non_www_status': www_non_www_status,
                'robots_txt_status': robots_txt_status,
                'open_graph_tags_status': open_graph_tags_status,
                'structured_data_status': structured_data_status,
                'images_expires_header_status': images_expires_header_status,
                'js_minified_status': js_minified_status,
                'css_minified_status': css_minified_status,
                'number_of_requests_status': number_of_requests_status,
                'total_requests': total_requests,
                'unique_requests': unique_requests,
                'page_size_status': page_size_status,
                'page_size': page_size,
                'load_time_status': load_time_status,
                'load_time': load_time,
                'response_time_status': response_time_status,
                'response_time': response_time,
                'directory_listing_status': directory_listing_status,
                'google_safe_browsing_status': google_safe_browsing_status,
                'https_status': https_status,
                'seo_score': 0  # initialize seo_score
            }

            results.append(result)

        except (requests.exceptions.RequestException, requests.exceptions.ConnectionError, requests.exceptions.Timeout, socket.gaierror):
            result = {
                'url': full_url,
                'has_title': False,
                'title_length': 0,
                'title_status': 'error',
                'title': '',
                'has_description': False,
                'description_length': 0,
                'description_status': 'error',
                'description': '',
                'keywords_status': False,
                'h1_content_status': False,
                'h2_content_status': False,
                'images_alt_text_status': False,
                'canonical_tag_status': False,
                'noindex_tag_status': False,
                'www_non_www_status': False,
                'robots_txt_status': False,
                'open_graph_tags_status': False,
                'structured_data_status': False,
                'images_expires_header_status': False,
                'js_minified_status': False,
                'css_minified_status': False,
                'number_of_requests_status': False,
                'total_requests': 0,
                'unique_requests': 0,
                'page_size_status': False,
                'page_size': 0,
                'load_time_status': False,
                'load_time': 0,
                'response_time_status': False,
                'response_time': 0,
                'directory_listing_status': False,
                'google_safe_browsing_status': False,
                'https_status': False,
                'seo_score': 0  # initialize seo_score
            }

            results.append(result)

        # calculate seo score
        score = (1 if result['title_status'] == 'valid' else 0) + \
                (1 if result['description_status'] == 'valid' else 0) + \
                (1 if result['keywords_status'] else 0) + \
                (1 if result['h1_content_status'] else 0) + \
                (1 if result['h2_content_status'] else 0) + \
                (1 if result['images_alt_text_status'] else 0) + \
                (1 if result['canonical_tag_status'] else 0) + \
                (1 if result['noindex_tag_status'] else 0) + \
                (1 if result['www_non_www_status'] else 0) + \
                (1 if result['robots_txt_status'] else 0) + \
                (1 if result['open_graph_tags_status'] else 0) + \
                (1 if result['structured_data_status'] else 0) + \
                (1 if result['images_expires_header_status'] else 0) + \
                (1 if result['js_minified_status'] else 0) + \
                (1 if result['css_minified_status'] else 0) + \
                (1 if result['number_of_requests_status'] else 0) + \
                (1 if result['page_size_status'] else 0) + \
                (1 if result['load_time_status'] else 0) + \
                (1 if result['response_time_status'] else 0) + \
                (1 if result['directory_listing_status'] else 0) + \
                (1 if result['google_safe_browsing_status'] else 0) + \
                (1 if result['https_status'] else 0)
        seo_score = (score / 22) * 100  # to calculate the score out of 100%
        result['seo_score'] = seo_score
        print(f"\n\n\nurl: {result['url']}, seo score: {seo_score:.2f}%")

        print(f"Basic SEO:\n"
              f"  Title: {result['title']}\n"
              f"  Title Length: {result['title_length']} characters\n"
              f"  Title Status: {result['title_status']}\n"
              f"  Description: {result['description']}\n"
              f"  Description Length: {result['description_length']} characters\n"
              f"  Description Status: {result['description_status']}\n"
              f"  Keywords Status: {result['keywords_status']}\n"
              f"  H1 Content Status: {result['h1_content_status']}\n"
              f"  H2 Content Status: {result['h2_content_status']}\n"
              f"  Images Alt Text Status: {result['images_alt_text_status']}\n")

        print(f"Advanced SEO:\n"
              f"  Canonical Tag Status: {result['canonical_tag_status']}\n"
              f"  Noindex Tag Status: {result['noindex_tag_status']}\n"
              f"  WWW and Non-WWW Status: {result['www_non_www_status']}\n"
              f"  Robots.txt Status: {result['robots_txt_status']}\n"
              f"  Open Graph Tags Status: {result['open_graph_tags_status']}\n"
              f"  Structured Data Status: {result['structured_data_status']}\n")

        print(f"Performance:\n"
              f"  Images Expires Header Status: {result['images_expires_header_status']}\n"
              f"  JS Minified Status: {result['js_minified_status']}\n"
              f"  CSS Minified Status: {result['css_minified_status']}\n"
              f"  Number of Requests Status: {result['number_of_requests_status']} (total requests: {result['total_requests']}, unique requests: {result['unique_requests']})\n"
              f"  Page Size Status: {result['page_size_status']} (size: {result['page_size']} KB)\n"
              f"  Load Time Status: {result['load_time_status']} (load time: {result['load_time']} seconds)\n"
              f"  Response Time Status: {result['response_time_status']} (response time: {result['response_time']:.4f} seconds)\n")

        print(f"Security:\n"
              f"  Directory Listing Status: {result['directory_listing_status']}\n"
              f"  Google Safe Browsing Status: {result['google_safe_browsing_status']}\n"
              f"  HTTPS Status: {result['https_status']}\n")

    # sort results by SEO score in descending order
    sorted_results = sorted(results, key=lambda x: x['seo_score'], reverse=True)

    # save results to an HTML file
    with open('seo_results.html', 'w', encoding='utf-8') as html_file:
        html_file.write('<html><head><title>SEO Results</title></head><body>')
        html_file.write('<h1>SEO Results</h1>')
        for result in sorted_results:
            html_file.write(f'<h2>URL: {result["url"]}</h2>')
            html_file.write('<h3>SEO Score: {:.2f}%</h3>'.format(result['seo_score']))
            
            html_file.write('<h3>Basic SEO</h3>')
            html_file.write('<ul>')
            html_file.write(f'<li>Title: {result["title"]}</li>')
            html_file.write(f'<li>Title Length: {result["title_length"]} characters</li>')
            html_file.write(f'<li>Title Status: {result["title_status"]}</li>')
            html_file.write(f'<li>Description: {result["description"]}</li>')
            html_file.write(f'<li>Description Length: {result["description_length"]} characters</li>')
            html_file.write(f'<li>Description Status: {result["description_status"]}</li>')
            html_file.write(f'<li>Keywords Status: {result["keywords_status"]}</li>')
            html_file.write(f'<li>H1 Content Status: {result["h1_content_status"]}</li>')
            html_file.write(f'<li>H2 Content Status: {result["h2_content_status"]}</li>')
            html_file.write(f'<li>Images Alt Text Status: {result["images_alt_text_status"]}</li>')
            html_file.write('</ul>')

            html_file.write('<h3>Advanced SEO</h3>')
            html_file.write('<ul>')
            html_file.write(f'<li>Canonical Tag Status: {result["canonical_tag_status"]}</li>')
            html_file.write(f'<li>Noindex Tag Status: {result["noindex_tag_status"]}</li>')
            html_file.write(f'<li>WWW and Non-WWW Status: {result["www_non_www_status"]}</li>')
            html_file.write(f'<li>Robots.txt Status: {result["robots_txt_status"]}</li>')
            html_file.write(f'<li>Open Graph Tags Status: {result["open_graph_tags_status"]}</li>')
            html_file.write(f'<li>Structured Data Status: {result["structured_data_status"]}</li>')
            html_file.write('</ul>')

            html_file.write('<h3>Performance</h3>')
            html_file.write('<ul>')
            html_file.write(f'<li>Images Expires Header Status: {result["images_expires_header_status"]}</li>')
            html_file.write(f'<li>JS Minified Status: {result["js_minified_status"]}</li>')
            html_file.write(f'<li>CSS Minified Status: {result["css_minified_status"]}</li>')
            html_file.write(f'<li>Number of Requests Status: {result["number_of_requests_status"]} (total requests: {result["total_requests"]}, unique requests: {result["unique_requests"]})</li>')
            html_file.write(f'<li>Page Size Status: {result["page_size_status"]} (size: {result["page_size"]} KB)</li>')
            html_file.write(f'<li>Load Time Status: {result["load_time_status"]} (load time: {result["load_time"]} seconds)</li>')
            html_file.write(f'<li>Response Time Status: {result["response_time_status"]} (response time: {result["response_time"]:.4f} seconds)</li>')
            html_file.write('</ul>')

            html_file.write('<h3>Security</h3>')
            html_file.write('<ul>')
            html_file.write(f'<li>Directory Listing Status: {result["directory_listing_status"]}</li>')
            html_file.write(f'<li>Google Safe Browsing Status: {result["google_safe_browsing_status"]}</li>')
            html_file.write(f'<li>HTTPS Status: {result["https_status"]}</li>')
            html_file.write('</ul>')

        html_file.write('</body></html>')

main()
# Out:
# url: https://www.haberturk.com/images/common/manifest/180x180.png, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 3.447265625 KB)
#   Load Time Status: True (load time: 0.06297588348388672 seconds)
#   Response Time Status: True (response time: 0.0648 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/images/common/favicon/32x32.png, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.8916015625 KB)
#   Load Time Status: True (load time: 0.011125564575195312 seconds)
#   Response Time Status: True (response time: 0.0502 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/images/common/favicon/16x16.png, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.5166015625 KB)
#   Load Time Status: True (load time: 0.05585002899169922 seconds)
#   Response Time Status: True (response time: 0.0485 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/images/common/favicon/favicon.ico?v=001, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 3.447265625 KB)
#   Load Time Status: True (load time: 0.010546445846557617 seconds)
#   Response Time Status: True (response time: 0.0454 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/manifest.webmanifest, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.7265625 KB)
#   Load Time Status: True (load time: 0.008000373840332031 seconds)
#   Response Time Status: True (response time: 0.0527 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.haberturk.com, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.017578125 KB)
#   Load Time Status: True (load time: 0.06183457374572754 seconds)
#   Response Time Status: True (response time: 0.0474 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://adsp.haberturk.com, seo score: 54.55%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.1416015625 KB)
#   Load Time Status: True (load time: 0.08223843574523926 seconds)
#   Response Time Status: True (response time: 0.0461 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.hthayat.com, seo score: 45.45%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: False (size: unknown size KB)
#   Load Time Status: False (load time: 2.7176754474639893 seconds)
#   Response Time Status: True (response time: 0.0718 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://geoim.bloomberght.com, seo score: 59.09%
# Basic SEO:
#   Title: 403 Forbidden
#   Title Length: 13 characters
#   Title Status: too short
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.158203125 KB)
#   Load Time Status: True (load time: 0.06482839584350586 seconds)
#   Response Time Status: True (response time: 0.1345 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.showtv.com.tr, seo score: 59.09%
# Basic SEO:
#   Title: 403 Forbidden
#   Title Length: 13 characters
#   Title Status: too short
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.158203125 KB)
#   Load Time Status: True (load time: 0.14375901222229004 seconds)
#   Response Time Status: True (response time: 0.0572 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://mo.ciner.com.tr, seo score: 59.09%
# Basic SEO:
#   Title: 403 Forbidden
#   Title Length: 13 characters
#   Title Status: too short
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.158203125 KB)
#   Load Time Status: True (load time: 0.06681656837463379 seconds)
#   Response Time Status: True (response time: 0.0636 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://static.criteo.net, seo score: 50.00%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 0.0419921875 KB)
#   Load Time Status: True (load time: 0.182450532913208 seconds)
#   Response Time Status: True (response time: 0.1773 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://pagead2.googlesyndication.com, seo score: 63.64%
# Basic SEO:
#   Title: Error 404 (Not Found)!!1
#   Title Length: 24 characters
#   Title Status: valid
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 1.5244140625 KB)
#   Load Time Status: True (load time: 0.20492029190063477 seconds)
#   Response Time Status: True (response time: 0.1620 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
# error fetching image data:image/png;base64,...: No connection adapters were found for 'data:image/png;base64,...'
#
#
#
# url: https://www.google.com, seo score: 54.55%
# Basic SEO:
#   Title: Google
#   Title Length: 6 characters
#   Title Status: too short
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 3, unique requests: 3)
#   Page Size Status: True (size: 20.1025390625 KB)
#   Load Time Status: True (load time: 0.8387300968170166 seconds)
#   Response Time Status: False (response time: 0.4528 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.google-analytics.com, seo score: 77.27%
# Basic SEO:
#   Title: Analytics Tools & Solutions for Your Business - Google Analytics
#   Title Length: 64 characters
#   Title Status: valid
#   Description: Google Analytics gives you the tools you need to better understand your customers. You can then use those business insights to take action, such as improving your website, creating tailored audience lists, and more.
#   Description Length: 215 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 20, unique requests: 20)
#   Page Size Status: False (size: 115.638671875 KB)
#   Load Time Status: True (load time: 0.5896804332733154 seconds)
#   Response Time Status: False (response time: 0.7224 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.googletagmanager.com, seo score: 54.55%
# Basic SEO:
#   Title: Error 404 (Not Found)!!1
#   Title Length: 24 characters
#   Title Status: valid
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 1.5185546875 KB)
#   Load Time Status: True (load time: 1.1578607559204102 seconds)
#   Response Time Status: False (response time: 0.2240 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.googletagservices.com, seo score: 59.09%
# Basic SEO:
#   Title: Error 404 (Not Found)!!1
#   Title Length: 24 characters
#   Title Status: valid
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 1.5244140625 KB)
#   Load Time Status: True (load time: 0.18101191520690918 seconds)
#   Response Time Status: True (response time: 0.1702 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://securepubads.g.doubleclick.net, seo score: 59.09%
# Basic SEO:
#   Title: Error 404 (Not Found)!!1
#   Title Length: 24 characters
#   Title Status: valid
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 1.5244140625 KB)
#   Load Time Status: True (load time: 0.22206449508666992 seconds)
#   Response Time Status: False (response time: 0.2169 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com, seo score: 72.73%
# Basic SEO:
#   Title: Habertürk - Güncel Haberler, Son Dakika Haberleri ve Günün Haberleri
#   Title Length: 68 characters
#   Title Status: valid
#   Description: Haberler, son dakika haberleri ve en son gelişmeler Habertürk'te! Gazete haberleri, güncel olaylar ve ekonomi, magazin, gündem, spor haberi Türkiye'nin en büyük internet gazetesinde!
#   Description Length: 182 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: False
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 411, unique requests: 11)
#   Page Size Status: False (size: 507.7041015625 KB)
#   Load Time Status: True (load time: 0.7521300315856934 seconds)
#   Response Time Status: True (response time: 0.0594 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://m.haberturk.com, seo score: 68.18%
# Basic SEO:
#   Title: Habertürk - Güncel Haberler, Son Dakika Haberleri ve Günün Haberleri
#   Title Length: 68 characters
#   Title Status: valid
#   Description: Haberler, son dakika haberleri ve en son gelişmeler Habertürk'te! Gazete haberleri, güncel olaylar ve ekonomi, magazin, gündem, spor haberi Türkiye'nin en büyük internet gazetesinde!
#   Description Length: 182 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: False
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 355, unique requests: 10)
#   Page Size Status: False (size: 490.31640625 KB)
#   Load Time Status: True (load time: 0.779207706451416 seconds)
#   Response Time Status: True (response time: 0.0800 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/css/desktop/style.css?v=252, seo score: 59.09%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: False (size: 134.0439453125 KB)
#   Load Time Status: True (load time: 0.06385922431945801 seconds)
#   Response Time Status: True (response time: 0.0604 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.haberturk.com/l/2024/06/19/ver1718799771/3696380/jpg/320x640, seo score: 40.91%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: False (size: 58.3486328125 KB)
#   Load Time Status: True (load time: 0.026936769485473633 seconds)
#   Response Time Status: True (response time: 0.0734 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.haberturk.com/l/2024/06/20/ver1718831744/3696460/jpg/320x640, seo score: 40.91%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: True (size: 49.3955078125 KB)
#   Load Time Status: True (load time: 0.13942575454711914 seconds)
#   Response Time Status: False (response time: 0.2226 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.haberturk.com/l/2024/06/20/ver1718863122/3696489_manset/jpg/640x640, seo score: 40.91%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: False (size: 129.6220703125 KB)
#   Load Time Status: True (load time: 0.02588057518005371 seconds)
#   Response Time Status: True (response time: 0.0938 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://im.haberturk.com/l/2024/06/20/ver1718858199/3696483_manset/jpg/640x640, seo score: 40.91%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: False
#   Robots.txt Status: False
#   Open Graph Tags Status: False
#   Structured Data Status: False
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 0, unique requests: 0)
#   Page Size Status: False (size: 81.1806640625 KB)
#   Load Time Status: True (load time: 0.028922319412231445 seconds)
#   Response Time Status: True (response time: 0.0608 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/adscbg/cbglout.js, seo score: 63.64%
# Basic SEO:
#   Title:
#   Title Length: 0 characters
#   Title Status: no title
#   Description:
#   Description Length: 0 characters
#   Description Status: no description
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: False
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: False
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: True
#   JS Minified Status: True
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 1, unique requests: 1)
#   Page Size Status: False (size: 70.330078125 KB)
#   Load Time Status: True (load time: 0.04742884635925293 seconds)
#   Response Time Status: True (response time: 0.1790 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi, seo score: 77.27%
# Basic SEO:
#   Title: Ekonomi Haberleri - Finansal Gelişmeler ve Son Dakika Ekonomi Haberi
#   Title Length: 68 characters
#   Title Status: valid
#   Description: Türkiye ve dünyadan ekonomi haberleri, piyasalardaki son gelişmeler; borsa, dolar, euro, altın fiyatları Habertürk Ekonomi sayfalarında. Ekonominin nabzını Habertürk ile tutun.
#   Description Length: 176 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 110, unique requests: 13)
#   Page Size Status: False (size: 221.857421875 KB)
#   Load Time Status: True (load time: 0.7482681274414062 seconds)
#   Response Time Status: True (response time: 0.0500 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/altin, seo score: 77.27%
# Basic SEO:
#   Title: Altın Fiyatları 2023 Bugün - Canlı Altın Fiyatları Takibi ve Altın Kuru Fiyatı
#   Title Length: 78 characters
#   Title Status: too long
#   Description: Altın fiyatları canlı ve grafiklerle takip edin. Altın Fiyatları sayfası ile Kapalıçarşı ve serbest piyasadaki altın fiyatlarını öğrenin. 2023'e ilişkin güncel altın kuru hesaplama ve bugün altın fiyatları ne kadar oldu sorusuna cevap bulun.
#   Description Length: 241 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 32, unique requests: 12)
#   Page Size Status: False (size: 90.431640625 KB)
#   Load Time Status: True (load time: 0.8314106464385986 seconds)
#   Response Time Status: True (response time: 0.0740 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/piyasa/88-dolar, seo score: 77.27%
# Basic SEO:
#   Title: Dolar Bugün Ne Kadar? Canlı Dolar Kuru TL Fiyatı Hesaplama ile 1 Dolar Kaç TL?
#   Title Length: 78 characters
#   Title Status: too long
#   Description: Dolar kuru canlı ve anlık alış satış TL fiyatı Habertürk'te! Saatlik, günlük, aylık grafiklerle Harem Kapalıçarşı ve Merkez Bankası'nın güncel ABD dolar kuru hesaplama ekranı ile bugün 1 dolar kuru ne kadar oldu sorusuna cevap bulabilirsiniz.
#   Description Length: 242 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 31, unique requests: 12)
#   Page Size Status: False (size: 114.5380859375 KB)
#   Load Time Status: True (load time: 1.137727975845337 seconds)
#   Response Time Status: True (response time: 0.0718 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/piyasa/89-euro, seo score: 77.27%
# Basic SEO:
#   Title: Euro Bugün Ne Kadar? Canlı Euro Kuru Alış Satış TL Fiyatı ile Euro Hesaplama
#   Title Length: 76 characters
#   Title Status: too long
#   Description: Euro kuru canlı ve anlık alış satış fiyatı Habertürk'te! Saatlik, günlük, aylık grafiklerle Harem Kapalıçarşı ve Merkez Bankası'nın güncel avro kuru hesaplama ekranı ile bugün 1 euro ne kadar, kaç TL sorusuna yanıt bulabilirsiniz.
#   Description Length: 230 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 31, unique requests: 12)
#   Page Size Status: False (size: 114.5654296875 KB)
#   Load Time Status: True (load time: 0.5777058601379395 seconds)
#   Response Time Status: True (response time: 0.0509 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/altin/610-gram-altin, seo score: 72.73%
# Basic SEO:
#   Title: Gram Altın Fiyatı - Canlı Gram Altın Alış ve Satış Fiyatları Bugün Ne Kadar?
#   Title Length: 76 characters
#   Title Status: too long
#   Description: Gram altın fiyatı canlı ve güncel rakamları buradan öğrenin. 2023 yılına ilişkin saatlik, günlük ve aylık grafiklerle güncel gram altın fiyatları anlık alış/satış rakamlarını görün. Gram altın fiyatları ne kadar oldu sorusunun cevabı için takipte kalın.
#   Description Length: 253 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 32, unique requests: 12)
#   Page Size Status: False (size: 82.810546875 KB)
#   Load Time Status: True (load time: 0.5648963451385498 seconds)
#   Response Time Status: True (response time: 0.0599 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/piyasa/1947-faiz, seo score: 86.36%
# Basic SEO:
#   Title: TAHVIL HİSSE FİYATLARI | TR 2 YILLIK TAHVİL - HTEKONOMİ
#   Title Length: 55 characters
#   Title Status: valid
#   Description: TAHVIL Hisse Fiyatları | TR 2 YILLIK TAHVİL ile ilgili finansal bilgiler ve haberler.
#   Description Length: 85 characters
#   Description Status: valid
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 20, unique requests: 12)
#   Page Size Status: False (size: 72.259765625 KB)
#   Load Time Status: True (load time: 0.8576922416687012 seconds)
#   Response Time Status: True (response time: 0.0862 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/piyasa/2211-bitcoin, seo score: 72.73%
# Basic SEO:
#   Title: Bitcoin Bugün Ne Kadar? - Canlı Bitcoin Kuru Alış Satış TL Fiyatı ve Güncel Endeks Hesaplama
#   Title Length: 92 characters
#   Title Status: too long
#   Description: Bitcoin kuru canlı ve anlık alış satış fiyatı Habertürk'te! Saatlik, günlük, aylık grafik ile güncel Bitcoin kuru endeksi hesaplama ve bugün 1 dolar ne kadar, kaç TL sorusuna cevap bulabilirsiniz.
#   Description Length: 196 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 21, unique requests: 13)
#   Page Size Status: False (size: 67.4052734375 KB)
#   Load Time Status: True (load time: 0.5079035758972168 seconds)
#   Response Time Status: True (response time: 0.0731 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/ekonomi/borsa, seo score: 81.82%
# Basic SEO:
#   Title: CANLI BORSA Takip Ekranı - Borsa İstanbul (BIST) Anlık Hisse Verileri
#   Title Length: 69 characters
#   Title Status: valid
#   Description: Canlı borsa verilerini ve borsa hisselerine dair en son haberleri görüntüleyin. Borsa İstanbul'u (BİST) yorumlarla beraber Habertürk'te canlı ve anlık takip edin!
#   Description Length: 162 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 20, unique requests: 12)
#   Page Size Status: False (size: 141.8232421875 KB)
#   Load Time Status: True (load time: 0.5857820510864258 seconds)
#   Response Time Status: True (response time: 0.0577 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/canliyayin, seo score: 72.73%
# Basic SEO:
#   Title: Habertürk TV Canlı Yayın İzle
#   Title Length: 29 characters
#   Title Status: valid
#   Description: Habertürk TV canlı yayını izlemek için tıklayın. Habertürk'i canlı yayın sayfamızdan kesintisiz izleyebilirsiniz. Habertürk, Habertürk canlı, Habertürk canlı yayın, Habertürk izle, Habertürk canlı izle, Habertürk canlı yayını, Habertürk, Habertürk İZLE
#   Description Length: 252 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 35, unique requests: 16)
#   Page Size Status: False (size: 68.08203125 KB)
#   Load Time Status: True (load time: 1.1991872787475586 seconds)
#   Response Time Status: True (response time: 0.0472 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/, seo score: 72.73%
# Basic SEO:
#   Title: Habertürk - Güncel Haberler, Son Dakika Haberleri ve Günün Haberleri
#   Title Length: 68 characters
#   Title Status: valid
#   Description: Haberler, son dakika haberleri ve en son gelişmeler Habertürk'te! Gazete haberleri, güncel olaylar ve ekonomi, magazin, gündem, spor haberi Türkiye'nin en büyük internet gazetesinde!
#   Description Length: 182 characters
#   Description Status: too long
#   Keywords Status: True
#   H1 Content Status: False
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 411, unique requests: 11)
#   Page Size Status: False (size: 507.826171875 KB)
#   Load Time Status: True (load time: 0.7562196254730225 seconds)
#   Response Time Status: True (response time: 0.0611 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Adana/LTAG, seo score: 72.73%
# Basic SEO:
#   Title: Adana 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 56 characters
#   Title Status: valid
#   Description: Adana bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 157 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.5166015625 KB)
#   Load Time Status: True (load time: 1.0082616806030273 seconds)
#   Response Time Status: True (response time: 0.0593 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Adiyaman/LTDY, seo score: 72.73%
# Basic SEO:
#   Title: Adıyaman 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 59 characters
#   Title Status: valid
#   Description: Adıyaman bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 160 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.5166015625 KB)
#   Load Time Status: True (load time: 0.5674545764923096 seconds)
#   Response Time Status: True (response time: 0.0548 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Afyon/LTAF, seo score: 72.73%
# Basic SEO:
#   Title: Afyon 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 56 characters
#   Title Status: valid
#   Description: Afyon bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 157 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.5087890625 KB)
#   Load Time Status: True (load time: 0.5109639167785645 seconds)
#   Response Time Status: True (response time: 0.0609 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Agri/LTCB, seo score: 72.73%
# Basic SEO:
#   Title: Ağrı 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 55 characters
#   Title Status: valid
#   Description: Ağrı bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 156 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.5927734375 KB)
#   Load Time Status: True (load time: 0.5171644687652588 seconds)
#   Response Time Status: True (response time: 0.0464 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Amasya/LTT3, seo score: 72.73%
# Basic SEO:
#   Title: Amasya 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 57 characters
#   Title Status: valid
#   Description: Amasya bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 158 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.5263671875 KB)
#   Load Time Status: True (load time: 0.8163893222808838 seconds)
#   Response Time Status: True (response time: 0.0484 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Ankara/LTAD, seo score: 72.73%
# Basic SEO:
#   Title: Ankara 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 57 characters
#   Title Status: valid
#   Description: Ankara bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 158 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.5263671875 KB)
#   Load Time Status: True (load time: 0.5730934143066406 seconds)
#   Response Time Status: True (response time: 0.0591 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/havadurumu/Turkiye-TR/Antalya/TU0199, seo score: 72.73%
# Basic SEO:
#   Title: Antalya 5 Günlük Hava durumu tahminleri - Hava Durumu 2024
#   Title Length: 58 characters
#   Title Status: valid
#   Description: Antalya bugün ve yarının hava durumu tahminlerini bu sayfada bulabilirsiniz. 5 günlük hava durumu tahminleri sayfamızda yer almaktadır. İşte hava durumu raporu
#   Description Length: 159 characters
#   Description Status: valid
#   Keywords Status: False
#   H1 Content Status: False
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 68.509765625 KB)
#   Load Time Status: True (load time: 0.583714485168457 seconds)
#   Response Time Status: True (response time: 0.0570 seconds)
#
# Security:
#   Directory Listing Status: True
# ...
#   Page Size Status: False (size: 1142.3740234375 KB)
#   Load Time Status: True (load time: 0.8647522926330566 seconds)
#   Response Time Status: True (response time: 0.1611 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/atasozleri-ve-anlamlari, seo score: 68.18%
# Basic SEO:
#   Title: Atasözleri ve Anlamları - Kısa, Uzun En Çok Bilinen Atasözleri ile A'dan Z'ye Türkçe Atasözü Örnekleri
#   Title Length: 102 characters
#   Title Status: too long
#   Description: Türk atasözleri, Türk kültürünün önemli bir özetidir. Bu sayfada, Türk atasözleri anlamları ile atasözleri örnekleri hakkında bilgi edinebilirsiniz. Aynı zamanda, kısa, uzun atasözleri kökenleri ve A'dan Z'ye Türkçede en çok kullanılan atasözü anlamları için sayfamızı ziyaret edebilirsiniz.
#   Description Length: 291 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 20, unique requests: 15)
#   Page Size Status: False (size: 1082.5341796875 KB)
#   Load Time Status: True (load time: 1.6565008163452148 seconds)
#   Response Time Status: True (response time: 0.0730 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/deyimler-sozlugu, seo score: 68.18%
# Basic SEO:
#   Title: Türkçe Deyimler Sözlüğü - Deyimlerin Anlamları ve Kullanımı
#   Title Length: 59 characters
#   Title Status: valid
#   Description: Bu sayfa, Türkçe dilinde yaygın olarak kullanılan deyimlerin anlamları ve doğru kullanımını içermektedir. Ayrıca, Türkçe dilinin zenginliğini keşfetmek için harika bir kaynaktır. A'dan Z'ye, az bilinen, kısa, uzun ve kalıplaşmış deyimler ve örnekleri için sayfamızı ziyaret edin.
#   Description Length: 279 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 20, unique requests: 15)
#   Page Size Status: False (size: 4501.123046875 KB)
#   Load Time Status: False (load time: 5.6296913623809814 seconds)
#   Response Time Status: True (response time: 0.0756 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/cin-takvimi-cinsiyet-hesaplama, seo score: 72.73%
# Basic SEO:
#   Title: Çin Takvimi ile Bebek Cinsiyeti Hesaplama Aracı 2024
#   Title Length: 52 characters
#   Title Status: valid
#   Description: Çin Takvimi 2024 cinsiyet ve gebelik hesaplama aracı ile bebek cinsiyetinizi tahmin edin ve gebeliğinizin hangi haftasında olduğunuzu öğrenin. Çin takvimi 2024 yılına kadar güncellenmiştir ve ücretsiz kullanılabilir.
#   Description Length: 216 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 133.4951171875 KB)
#   Load Time Status: True (load time: 0.6284587383270264 seconds)
#   Response Time Status: True (response time: 0.0731 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/iett-sefer-saatleri-ve-otobus-duraklari, seo score: 72.73%
# Basic SEO:
#   Title: İETT Saatleri ve Otobüs Durakları - İETT Sefer Saatleri, Otobüs Hat Güzergahı ve Geçtiği Duraklar
#   Title Length: 97 characters
#   Title Status: too long
#   Description: İstanbul'da seyahat ederken İETT otobüslerini kullanmak isteyenler için, sayfamızda İETT saatleri, otobüs durakları, sefer saatleri, otobüs güzergahları ve geçtiği duraklar hakkında ayrıntılı bilgiler mevcuttur.
#   Description Length: 211 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 667.9931640625 KB)
#   Load Time Status: True (load time: 0.7348721027374268 seconds)
#   Response Time Status: True (response time: 0.0974 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/gebelik-hesaplama, seo score: 72.73%
# Basic SEO:
#   Title: Gebelik Hesaplama - Net Hamilelik Haftası Hesaplama Aracı
#   Title Length: 57 characters
#   Title Status: valid
#   Description: Gebelik hesaplama ekranı ile son adet gününüzü girerek kaç haftalık hamile olduğunuzu öğrenin. Gebelik haftası hesaplama aracı, doğru tahmini doğum tarihinizi belirler. Hemen hamilelik hesaplaması yapın!
#   Description Length: 203 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 56.0341796875 KB)
#   Load Time Status: True (load time: 1.5966532230377197 seconds)
#   Response Time Status: True (response time: 0.1496 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/yukselen-burc-hesaplama, seo score: 77.27%
# Basic SEO:
#   Title: Yükselen Burç Hesaplama 2024 - Burçlarınızı ve Yükselen Burcunuzu Keşfedin
#   Title Length: 74 characters
#   Title Status: valid
#   Description: Yükselen burç hesaplama ile doğum haritanızı analiz ederek burç yükseleninizi öğrenebilirsiniz. Burçlar hakkında daha fazla bilgi edinmek ve yükselen burcunuzu hesaplamak için yükselen burcu hesaplama aracımızı kullanabilirsiniz. Yükselen burç nasıl bulunur sorusunun yanıtı bu araçta!
#   Description Length: 285 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 17, unique requests: 12)
#   Page Size Status: False (size: 74.87109375 KB)
#   Load Time Status: True (load time: 0.5167117118835449 seconds)
#   Response Time Status: True (response time: 0.0549 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/yuzde-hesaplama, seo score: 72.73%
# Basic SEO:
#   Title: Yüzde Hesaplama – Yüzdelik Alma Formülü ile Yüzde Nasıl Hesaplanır?
#   Title Length: 67 characters
#   Title Status: valid
#   Description: Yüzde hesaplama, bir sayının diğer bir sayıya veya gruba göre oranını hesaplamak için kullanılır. Bu sayfadan hesap makinesinden yüzde hesaplama formülü hakkında bilgi edinebilir, maaş yüzde hesaplama ve yüzde indirim hesaplama gibi detaylara ulaşabilirsiniz.
#   Description Length: 259 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: False
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 16, unique requests: 11)
#   Page Size Status: False (size: 54.638671875 KB)
#   Load Time Status: True (load time: 0.5256662368774414 seconds)
#   Response Time Status: True (response time: 0.1963 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/gecmis-doviz-kurlari/, seo score: 72.73%
# Basic SEO:
#   Title: Geçmiş Döviz Kurları - Eski Yıllara Ait Döviz Kuru
#   Title Length: 50 characters
#   Title Status: valid
#   Description: Geçmiş döviz kurları ve eski yıllara ait döviz kuru bilgilerine hızlı ve kolay bir şekilde ulaşın. Tarihsel döviz kurları, analizler ve yatırım planlarınız için güvenilir kaynağınız. Merkez Bankası'nın açıkladığı geçmiş döviz kuru ile önceki yıllara ait döviz fiyatları hakkında bilgi sahibi olun
#   Description Length: 296 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: True (total requests: 15, unique requests: 10)
#   Page Size Status: False (size: 67.8408203125 KB)
#   Load Time Status: True (load time: 1.8752031326293945 seconds)
#   Response Time Status: False (response time: 0.2940 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/instagram-dondurma-nasil-yapilir-instagram-gecici-ve-kalici-hesap-dondurma-linki-2024-3671526, seo score: 63.64%
# Basic SEO:
#   Title: Instagram dondurma nasıl yapılır? Instagram geçici ve kalıcı hesap dondurma linki 2024
#   Title Length: 86 characters
#   Title Status: too long
#   Description: En fazla tercih edilen sosyal medya platformlarından olan ve her ay 1 milyar kullanıcı tarafından ziyaret edilen Instagram, günümüzün en trend ve popüler uygulamalarından. Kullanıcıların büyük bir kısmı günlük hayatları içinde gerek eğlenmek, gerekse bilgi almak için uygulamayı yoğun olarak kullanıyor. Ancak bazı kullanıcılar ise, çeşitli nedenlerden dolayı hesaplarını dondurmak isteyebiliyor. Bu işlemi nasıl yapacağını bilmeyen kullanıcılar, internet üzerinden çeşitli araştırmalar yaparak doğru şekilde Instagram dondurmanın nasıl yapılacağını araştırıyor. 2024 yılında geçici ya da kalıcı olarak Instagram dondurma nasıl yapılır adım adım...
#   Description Length: 648 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 112, unique requests: 13)
#   Page Size Status: False (size: 385.1806640625 KB)
#   Load Time Status: True (load time: 0.5954709053039551 seconds)
#   Response Time Status: False (response time: 0.2126 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/instagram-hesap-silme-nasil-yapilir-instagram-kalici-ve-gecici-hesap-silme-linki-2024-3671557, seo score: 59.09%
# Basic SEO:
#   Title: Instagram hesap silme nasıl yapılır? Instagram kalıcı ve geçici hesap silme linki 2024
#   Title Length: 86 characters
#   Title Status: too long
#   Description: Sosyal medya platformları arasından en çok tercih edilen uygulamaların başında yer alan Instagram, aylık 1 milyar üzerinde kullancı tarafından ziyaret ediliyor.  Kullanıcılar eğlenceden bilgi edinmeye, haber takibinden günlük stil önerilerine, yemek tariflerinden alışverişe kadar bir çok ihtiyacını uygulama üzerinden giderebiliyor. Bu nedenle uygulamayı kullanan kullanıcıların bir çoğu olduka memnun ancak  bazı kullanıcılar ise çeşitli sebeplerden dolayı Instagram hesaplarını silmek istiyor. Bu işlemin nasıl yapılacağını bilmeyen kullanıcılar, çeşitli araştırmalar yaparak Instagram hesabı silmenin nasıl yapılacağını öğrenmeye çalışıyor. ...
#   Description Length: 648 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: False
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 111, unique requests: 13)
#   Page Size Status: False (size: 381.5107421875 KB)
#   Load Time Status: True (load time: 0.7093567848205566 seconds)
#   Response Time Status: False (response time: 0.2552 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
#
#
#
#
# url: https://www.haberturk.com/2024-yilinda-kac-gun-tatil-olacak-2024-yili-resmi-tatil-gunleri-3645225, seo score: 72.73%
# Basic SEO:
#   Title: 2024 yılında kaç gün tatil olacak? 2024 yılı resmi tatil günleri
#   Title Length: 64 characters
#   Title Status: valid
#   Description: 2023’ü geride bırakmaya sayılı günler kala hem öğrenci hem de gerek kamu gerekse özel sektörde çalışanlar için önemli bir konu olan 2024 yılı resmi tatil günleri merak edilmeye başlandı. 2024 yılında resmi tatillerin bir kısmının hafta içine denk gelecek olması nedeniyle içinde bulunduğumuz 2023 ve daha önceki yıllara göre daha fazla resmi tatil bulunuyor.
#   Description Length: 358 characters
#   Description Status: too long
#   Keywords Status: False
#   H1 Content Status: True
#   H2 Content Status: True
#   Images Alt Text Status: True
#
# Advanced SEO:
#   Canonical Tag Status: True
#   Noindex Tag Status: True
#   WWW and Non-WWW Status: True
#   Robots.txt Status: True
#   Open Graph Tags Status: True
#   Structured Data Status: True
#
# Performance:
#   Images Expires Header Status: False
#   JS Minified Status: False
#   CSS Minified Status: True
#   Number of Requests Status: False (total requests: 111, unique requests: 14)
#   Page Size Status: False (size: 362.953125 KB)
#   Load Time Status: True (load time: 0.5993707180023193 seconds)
#   Response Time Status: True (response time: 0.0760 seconds)
#
# Security:
#   Directory Listing Status: True
#   Google Safe Browsing Status: True
#   HTTPS Status: True
